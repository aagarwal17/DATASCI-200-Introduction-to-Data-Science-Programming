# %%
sample_string='this is week 7'
print(sample_string)
type(sample_string)

#notice the difference
print(type(sample_string))

# %%
import inspect

sample_list=["tangerine","red apple","pineapple"]

#print(sample_list)

#print(type(sample_list))
sample_list.append("Bunch of grapes")
#print(sample_list)

inspect.getmembers(sample_list)
#dir(sample_list)

# %%
#str(123) 
#repr(123)

#str('hello')
#repr('hello')


#str([1, 2, 3]) 
#repr([1, 2, 3])

str(["Apple","Orange"])
repr(["Apple","Orange"])

# %%
import datetime
today = datetime.datetime.now()
 
# Prints readable format for date-time object
#print(str(today))
 
# prints the official format of date-time object
print(repr(today))

# %%
# DEFINE A CLASS
class airplane:
    """ Base class for all airplanes """
    min_base_seats = 0                     # NOTE: Class Attribute
    max_base_seats=0
    default_color="silver"
    default_seats="blue"
    airline_brandnames=[]

          
    def show_capacity(self):                # add a method to get data 
        print(self.min_base_seats, self.max_base_seats)

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)

# %%
sw=airplane()

sw.show_capacity()
#print(str(sw))
print(repr(sw))
sw.order_airline("SW")

delta=airplane()
delta.order_airline("Delta")

# %%
# DEFINE A CLASS
class airplane:
    """ Base class for all airplanes """
    min_base_seats = 0                     # NOTE: Class Attribute
    max_base_seats=0
    default_color="silver"
    default_seats="blue"
    airline_brandnames=[]

          
    def show_capacity(self):                # add a method to get data 
        print(self.min_base_seats, self.max_base_seats)

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        


    # For call to repr(). Prints object's information
    def __repr__(self):
        return 'new_repr(%s, %s)' % (self.default_color, self.default_seats)    
 
    # For call to str(). Prints readable form
    def __str__(self):
        return '%s + i%s' % (self.default_color, self.default_seats)

# %%
sw=airplane()
sw.show_capacity()
print(str(sw))
print(repr(sw))
#sw.order_airline("AA")
# Out:
# 0 0
# silver + iblue
# new_repr(silver, blue)

# %%
# DEFINE A CLASS
class airplane:
    """ Base class for all airplanes """
    min_base_seats = 0                     # NOTE: Class Attribute
    max_base_seats=500
    default_color="silver"
    default_seats="blue"
    airline_brandnames=[]

    #def __init__(self, name,yop, min_capacity = 100):
    def __init__(self, name,yop,seat_count):
        self.airline_brandnames.append(name)
        self.yop=yop
        self.min_base_seats=seat_count        # Instance Attribute
        
    def show_capacity(self):                # add a method to get data 
        print(self.min_base_seats, self.max_base_seats)

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        

#### Comment this out and show overriding 
    # For call to repr(). Prints object's information
    def __repr__(self):
        return 'new_repr(%s, %s)' % (self.default_color, self.default_seats)    
 
    # For call to str(). Prints readable form
    def __str__(self):
        return '%s + i%s' % (self.default_color, self.default_seats)  
#### Comment this out and show overriding

# %%
sw=airplane("Delta",1999,40)

#sw.show_capacity()

str(sw)
#Another way
print(sw)

#repr(sw)
#Another way 
#sw

#sw.order_airline("AA")

# %%
#Dot operator and @property example
# DEFINE A CLASS
class airplane:
    """ Base class for all airplanes """
    min_base_seats = 0                     # NOTE: Class Attribute
    max_base_seats=500
    default_color="silver"
    default_seats="blue"
    airline_brandnames=[]
    

    #def __init__(self, name,yop, min_capacity = 100):
    def __init__(self, name,yop,seat_count):
        self.airline_brandnames.append(name)
        self.yop=yop
        self.min_base_seats=seat_count        # Instance Attribute
    
    @property
    def show_capacity(self):                # add a method to get data 
        print(self.min_base_seats, self.max_base_seats)

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        

#### Comment this out and show overriding 
    # For call to repr(). Prints object's information
    def __repr__(self):
        return 'new_repr(%s, %s)' % (self.default_color, self.default_seats)    
 
    # For call to str(). Prints readable form
    def __str__(self):
        return '%s + i%s' % (self.default_color, self.default_seats)  
#### Comment this out and show overriding

# %%
new_delta=airplane("Delta",1999,40)

sw.show_capacity
#non property way was method 
#sw.show_capacity()

#str(sw)
#Another way
#print(sw)

#repr(sw)
#Another way 
#sw

#sw.order_airline("AA")

# %% [markdown]
# Go down a simpler example for the last few demos

# %%
#demo classes defined from another
# demo 2: Note B's instance of C

class A:
    def __init__(self):
        self.x = 5
        
class B:
    def __init__(self, x):
        self.x = x
        self.c = C(100)
        
        print("\nAccess c from B: ",self.c.x)
        
class C:
    def __init__(self, x):
        self.x = x
        
class Main:

    a = A()
    b = B(20)
    
    # access from Main
    print(a.x)
    print(b.x)
    print("\n")
    print(b.c.x)

# ---------------
main = Main()

# %%
dir(list)

# %%
dir(Student)

# %%
# demo 5:
# Getting around protection using @ property decorator
# @property by itself acts like a GET
class Student:

    def __init__(self, name):
        self.__name = name

 
    def name(self):
        return self.__name

# %%
s = Student('Steve')
print(s.name())  #'Steve'

# %% [markdown]
# Week 8 - Still on the same example as week 7

# %%
#Same Example as week 7 
#Constructor , create a child object
#Access method inside the parent class from object

# DEFINE A CLASS
class airplane:
    """ Base class for all airplanes """
    min_base_seats = 0                     # NOTE: Class Attribute
    max_base_seats=500
    default_color="silver"
    default_seats="blue"
    airline_brandnames=[]
    

    #def __init__(self, name,yop, min_capacity = 100):
    def __init__(self, name,yop,seat_count):
        self.airline_brandnames.append(name)
        self.yop=yop
        self.min_base_seats=seat_count        # Instance Attribute
    
    def show_capacity(self):                # add a method to get data 
        self.max_base_seats=self.min_base_seats
        print("Flight capacity:"+str(self.max_base_seats))

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        

#Create a child class
sw_craft= airplane('SW',2020,125)
#print(sw_craft)
sw_craft.show_capacity()

# %%
#Create a new child class , inherit everything from parent class
# DEFINE A CLASS
class airplane:
    """ Base class for all airplanes """
    min_base_seats = 0                     # NOTE: Class Attribute
    max_base_seats=500
    default_color="silver"
    default_seats="blue"
    airline_brandnames=[]
    

    #def __init__(self, name,yop, min_capacity = 100):
    def __init__(self, name,yop,seat_count):
        self.airline_brandnames.append(name)
        self.yop=yop
        self.min_base_seats=seat_count        # Instance Attribute
    
    def show_capacity(self):                # add a method to get data 
        self.max_base_seats=self.min_base_seats
        print("Flight capacity:"+str(self.max_base_seats))

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        

#Create a second class - child class
class private_airplane(airplane):
    pass

#dir(private_airplane)

pj=private_airplane('gulfstream100',2021,16)
pj.show_capacity()

# %%
#Create a new class , override constructor and a method from parent
# DEFINE A CLASS
class airplane:
    """ Base class for all airplanes """
    min_base_seats = 0                     # NOTE: Class Attribute
    max_base_seats=500
    default_color="silver"
    default_seats="blue"
    airline_brandnames=[]
    

    #def __init__(self, name,yop, min_capacity = 100):
    def __init__(self, name,yop,seat_count):
        self.airline_brandnames.append(name)
        self.yop=yop
        self.min_base_seats=seat_count        # Instance Attribute
    
    def show_capacity(self):                # add a method to get data 
        self.max_base_seats=self.min_base_seats
        print("Flight capacity:"+str(self.max_base_seats))

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        

#Create a second class - child class
class private_airplane(airplane):
  
    def __init__(self, name,yop,seat_count):
        self.airline_brandnames.append(name)
        self.yop=yop
        self.min_base_seats=2
        self.max_base_seats=seat_count 
    
    def show_capacity(self):                # add a method to get data 
    
        print("Flight capacity:"+str(self.max_base_seats))

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        


#dir(private_airplane)

#creating object here from child class
pj=private_airplane('gulfstream100',2021,16)
pj.show_capacity()
pj.min_base_seats

# %%
#Add a new method , unique to child class
#Create a new class , override class attributes from parent
# DEFINE A CLASS
class airplane:
    """ Base class for all airplanes """
    min_base_seats = 0                     # NOTE: Class Attribute
    max_base_seats=500
    default_color="silver"
    default_seats="blue"
    airline_brandnames=[]
    

    #def __init__(self, name,yop, min_capacity = 100):
    def __init__(self, name,yop,seat_count):
        self.airline_brandnames.append(name)
        self.yop=yop
        self.min_base_seats=seat_count        # Instance Attribute
    
    def show_capacity(self):                # add a method to get data 
        self.max_base_seats=self.min_base_seats
        print("Flight capacity:"+str(self.max_base_seats))

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        

#Create a second class - child class
class private_airplane(airplane):

    default_color="Gold"
    default_seats="Gold"

    def __init__(self, name,yop,seat_count):
        self.airline_brandnames.append(name)
        self.yop=yop
        self.min_base_seats=2
        self.max_base_seats=seat_count 
    
    def show_capacity(self):                # add a method to get data 
    
        print("Flight capacity:"+str(self.max_base_seats))

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        
    
    def seat_config(self):
        if(self.max_base_seats%2 ==0):
            print("No Swivel")
        else:
            print("Swivel possible")
        


#dir(private_airplane)

pj=private_airplane('gulfstream100',2021,16)
pj.show_capacity()
pj.min_base_seats
print(pj.default_color)
print(pj.default_seats)

pj.seat_config()

# %%
#Can i inherit the parent's class and improve (extend) it  ? YES 
# DEFINE A CLASS
class airplane:
    """ Base class for all airplanes """
    min_base_seats = 0                     # NOTE: Class Attribute
    max_base_seats=500
    default_color="silver"
    default_seats="blue"
    airline_brandnames=[]
    

    #def __init__(self, name,yop, min_capacity = 100):
    def __init__(self, name,yop,seat_count):
        self.airline_brandnames.append(name)
        self.yop=yop
        self.min_base_seats=seat_count        # Instance Attribute
    
    def show_capacity(self):                # add a method to get data 
        self.max_base_seats=self.min_base_seats
        print("Flight capacity:"+str(self.max_base_seats))

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        

#Create a second class - child class
class private_airplane(airplane):

    default_color="Gold"
    default_seats="Gold"
    longest_flight_time_possible=0

    def __init__(self, name,yop,seat_count,ft):
        super().__init__(name,yop,seat_count) 
        self.longest_flight_time_possible=ft
    
    def show_capacity(self):                # add a method to get data 
    
        print("Flight capacity:"+str(self.max_base_seats))

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        
    
    def seat_config(self):
        if(self.max_base_seats%2 ==0):
            print("No Swivel")
        else:
            print("Swivel possible")
        


#dir(private_airplane)

pj=private_airplane('gulfstream100',2021,16,8)
pj.show_capacity()
pj.min_base_seats
print("Default+color: "+str(pj.default_color))
print("Default+Seats: "+str(pj.default_seats))
print("Longest duration: "+str(pj.longest_flight_time_possible))
pj.seat_config()
# Out:
# Flight capacity:500
# Default+color: Gold
# Default+Seats: Gold
# Longest duration: 18
# No Swivel

# %%
delta=airplane("Delta",2015,250)
delta.seat_config()

# %% [markdown]
# Toy - polymorphism example

# %%
import unicodedata

class Mammal:
    # the __init__ accepts an argument for the species
    def __init__(self, species):
        self.__species = species
        
    # the show_speciees method displays a message about the mammal's species
    def show_species(self):
        print("I'm a ", self.__species)
        
    # make some generic sound ...
    def make_sound(self):
        print("\t\t \N{DOLPHIN} Roar of the Dolphin!")
        
class Dog(Mammal):
    
    # the __init__here calls the superclass's __init__ passing "Dog" as species
    def __init__(self):
        Mammal.__init__(self, "Dog")
        
    # here we'll override the superclass's make_sound() method.
    def make_sound(self):
        print("\t\t \N{DOG} Woof!")
        
class Cat(Mammal):
    
    # the __init__here calls the superclass's __init__ passing "Cat" as species
    def __init__(self):
        Mammal.__init__(self, "Cat")
        
    # here we'll override the superclass's make_sound() method.
    def make_sound(self):
        print("M e o o w ! \N{CAT}")
        
def animal_show():
    # create a Mammal, Dog, and Cat objects
    mammal = Mammal('Regular Mammal ')
    dog = Dog()
    cat = Cat()
    
    print("What do they say?")
    show_mammal_info(mammal)
    show_mammal_info(dog)
    show_mammal_info(cat)
    
# a way of getting info showing polymorphism.
def show_mammal_info(creature):
    creature.show_species()
    creature.make_sound()

    
if __name__ == "__main__":
    animal_show()
# Out:
# What do they say?
# I'm a  Regular Mammal
# 		 🐬 Roar of the Dolphin!
# I'm a  Dog
# 		 🐕 Woof!
# I'm a  Cat
# M e o o w ! 🐈

# %% [markdown]
# Go back to the example from cell 10 and code your own polymorphism example.

# %%
#answer is here - Paste during the class after break out - POLYMORPHISM
#Can i inherit the parent's class and improve (extend) it  ? YES 
# DEFINE A CLASS
class airplane:
    """ Base class for all airplanes """
    min_base_seats = 0                     # NOTE: Class Attribute
    max_base_seats=500
    default_color="silver"
    default_seats="blue"
    airline_brandnames=[]
    

    #def __init__(self, name,yop, min_capacity = 100):
    def __init__(self, name,yop,seat_count):
        self.airline_brandnames.append(name)
        self.yop=yop
        self.min_base_seats=seat_count        # Instance Attribute
    
    def show_capacity(self):                # add a method to get data 
        self.max_base_seats=self.min_base_seats
        print("Flight capacity :"+str(self.max_base_seats))

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        

#Create a second class - child class
class private_airplane(airplane):

    default_color="Gold"
    default_seats="Gold"
    longest_flight_time_possible=0

    def __init__(self, name,yop,seat_count,ft):
        super().__init__(name,yop,seat_count) 
        self.longest_flight_time_possible=ft
        
    def show_capacity(self):                # add a method to get data 
        self.max_base_seats=self.min_base_seats
        print("Flight capacity :"+str(self.max_base_seats))

    def order_airline(self,airline_name):
        self.airline_brandnames.append(airline_name)
        print(self.airline_brandnames)
        
    
    def seat_config(self):
        if(self.max_base_seats%2 ==0):
            print("No Swivel")
        else:
            print("Swivel possible")
        


#dir(private_airplane)
aa_craft= airplane('aa',2020,125)
aa_craft.show_capacity()

pj=private_airplane('gulfstream100',2021,16,8)
pj.show_capacity()
# Out:
# Flight capacity :125
# Flight capacity :16

# %% [markdown]
# Part 2: Magic Methods
# As we know our scripts inherit from Python a great number of **dunder** variables and methods. Python allows us access to those vars/methods and our own. We can leverage this idea to compare objects.
#
# Why? To compare variables, such as x = 5 to y = 20, is easy enough; but how to compare our own objects? We have to select some criterion or set of criteria that are comparable. Then we must override Python’s built-in ** such as **eq** equals, **lt**, **gt\_\_, and so on. Imagine if discussing financial institutions, we might wonder Bank is “bigger”? Bigger must be defined by some attribute of the object we can compare.
#
# We can override how python does comparisons - by overriding the magic methods.
#
# 🌈 Magic Methods
# **eq**(self, other) **ne**(self, other) **lt**(self, other)
# **gt**(self, other) **le**(self, other) **ge**(self, other)
# **add**(self, other) **sub**(self, other) **mul**(self, other)
# **floordiv**(self, other) **truediv**(self, other) **mod**(self, other)
# **pow**(self, other) **str**(self) **repr**(self)
# **len**(self) **name**(self) **main**

# %%
class Comparison:
    def __init__(self, a):
        self.a = a
    def __lt__(self, object2):
        return ((self.a )< object2.a)
    def __gt__(self, object2):
        return self.a > object2.a
    def __le__(self, object2):
        return self.a <= object2.a
    def __ge__(self, object2):
        return self.a >= object2.a
    def __eq__(self, object2):
        return self.a == object2.a
    def __ne__(self, object2):
        return self.a != object2.a
    
a = Comparison(1)
b = Comparison(2)

print(
    a < b,
    a > b,
    a <= b,
    a >= b,
    a == b,
    a != b
)
# Out:
# True False True False False True

# %%
class Comparison:
    def __init__(self, a):
        self.a = a
    def __lt__(self, object2):
        return ((2*self.a )< object2.a)
    def __gt__(self, object2):
        return self.a > object2.a
    def __le__(self, object2):
        return self.a <= object2.a
    def __ge__(self, object2):
        return self.a >= object2.a
    def __eq__(self, object2):
        return self.a == object2.a
    def __ne__(self, object2):
        return self.a != object2.a
    
a = Comparison(1)
b = Comparison(2)

print(
    a < b,
    a > b,
    a <= b,
    a >= b,
    a == b,
    a != b
)
# Out:
# False False True False False True

# %% [markdown]
# #static method
# static methods have a limited use case because, like class methods or any other methods within a class, they cannot access the properties of the class itself. However, when you need a utility function that doesn't access any properties of a class, but makes sense that it belongs to the class, we use static functions.
#
# #class method
# In Python, the @classmethod decorator is used to declare a method in the class as a class method that can be called using ClassName. MethodName() .

# %%
#Static and protected - WHY
""" ___________________________________
Example using CLASSMETHOD and STATIC
"""

class ProtectedBanks:
    """ Base class for all ProtectedBanks """
    __total_branches = 0

    def __init__(self, name, city, money_on_hand = 10000):
        self.name = name
        self.city = city
        self.no_of_transactions = 0
        self.__money_on_hand = money_on_hand
        ProtectedBanks.__total_branches += 1
        ProtectedBanks.preferred_currency = "USD"

    def how_much_in_vault(self):
        # print("$ in vault: ", moneyOnHand) - throws error now
        return self.__money_on_hand

    @classmethod
    def get_total_branches(cls):
        return cls.__total_branches
    
    @staticmethod
    def convert_from_USD_to_Yuan(amount):
        return amount * 0.16
    

mybank=ProtectedBanks("MYB",'Columbus')
#print(mybank)
#print(mybank.get_total_branches())
print(ProtectedBanks.get_total_branches())
# Out:
# 1
