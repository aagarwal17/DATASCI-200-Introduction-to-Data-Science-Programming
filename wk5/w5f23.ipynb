# %%
# %%html
# <script src="js/showNotes.js"></script>
# Out:
# <script src="js/showNotes.js"></script>

# %% [markdown]
# <p style="font-size:9px;">Version: Discussion version 1,
#     updated Feb 06, 2024. [&copy; 2023 gb]</p>
# <img src="images/ischool-banner.png" />
# <p>&nbsp;</p>
# <div style="height: 100px;color:#3B7EA1; font-size:24px; vertical-align:top; text-align:left;">
#     Computing for Data Science
#     <img style="width:20%; vertical-align:top; float: left; padding-right: 20px; display: block; margin-left: 0; margin-right: auto;"
#          src="images/ucb_logo.png"/>
# </div>

# %% [markdown]
# <hr />
# <h1 style="font-size:36; color: #003262;">Current Weekly Syllabus Topics</h1>
# <table width="100%;">
# <tr>
# <td style="text-align:left; vertical-align:top;">
# <ol>
#     <li>
#     <ul>
#         <li>Computer Architecture Basics;
#         Bash, Git, GitHub;</li>
#         <li>Command Line;</li>
#         <li>Manipulating Files &amp; Directories;
#         VIM;
#         Command Line intro;</li>
#     </ul>
# </li>
# <li>
#     <ul>
#     <li>Programming Lang Orientation:
#     <li>jupyter; python and command line;
#     objects &amp; types;
#     <li>variables (numbers and strings), formatting strings;</li>
#     <li>control while loops</li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Sequences</li>
#         <li>Lists, Tuples &amp; Mutability</li>
#         <li>Ranges</li>
#         <li>Dictionaries, Nested Lists &amp; dictionaries</li>
#     </ul>
# </li>
# </ol>
# </td>
# <td style="text-align:left; vertical-align:top;">
# <ol start="4">
# <li>
#     <ul>
#         <li>For Loops
#         <li>Exits
#         <li>Algorithms: searching [exhaustive, bisection, heron&rsquo;s methods]</li>
#         <li>Comprehensions</li>
#     </ul>
# </li>
# <li>
#     <ul style='background-color: #FDB515;'>
#         <li>Functions</li>
#         <li>Calling, Nesting</li>
#         <li>Namespaces, Global and Local Vars</li>
#         <li>Recursion; nested dictionaries &amp; recursion</li>
#         <li>Parameters</li>
#         <li>Exceptions</li>
#         <li>Lambdas</li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Complexity
#         <li>Measuring time and Steps</li>
#         <li>Big &Theta;</li>
#         <li>Searching and Subsequences
#         <li>Modules &amp; Packages</li>
#     </ul>
# </li>
# </ol>
# </td>
#     </tr>
# <table>
# <table width="100%">
#     <tr>
# <td style="text-align:left; vertical-align:top;">
# <ol start="7">
# <li>
#     <ul>
#         <li>Classes</li>
#         <li>Attributes, Binding</li>
#         <li>Initializing and Control</li>
#         <li>&UnderBar;&UnderBar;str&UnderBar;&UnderBar; and &UnderBar;&UnderBar;repr&UnderBar;&UnderBar;
#         </li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Object-Oriented Programming</li>
#         <li>Inheritance</li>
#         <li>Polymorphism</li>
#         <li>Magic Methods</li>
#     </ul>
# </li>
# <li>
#     <ul>
#     <li>PyData Ecosystem and Numpy</li>
#     <li>Boolean selection and types</li>
#     <li>Vectorization &amp; Multidimensional Arrays</li>
#     <li>Slicing and combining</li>
#     <li>Linear model in matrix form, Numpy</li>
#     </ul>
# </li>
# </ol>
# </td>
# <td style="text-align:left; vertical-align:top;">
# <ol start="10">
# <li>
#     <ul>
#         <li>Pandas &amp; Data Analysis</li>
#         <li>Series and Data Frames</li>
#         <li>Bracket index, log &amp; iloc</li>
#         <li>Functions and DataFrames</li>
#         <li>Sorting</li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Datasets and EDA</li>
#         <li>Fixing Data Issues (Cleansing)</li>
#         <li>Answering Questions</li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Plotting &amp; Visualization</li>
#         <li>Libraries (Matplotlib, Seaborn, etc.)</li>
#         <li>Plot features</li>
#     </ul>
# </li>
# </ol>
# </td>
# </tr>
# </table>
# <table width="100%">
# <tr>
# <td style="text-align:left; vertical-align:top;">
# <ol start="13">
#     <li>
#     <ul>
#         <li>Pandas Aggregation &amp; Group Operations</li>
#         <li>Series.groupby</li>
#         <li>DataFrame.groupby</li>
#         <li>Aggregation</li>
#         <li>Pivot Tables &amp; Crosstabs</li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Presentations (so no time to cover...
#         <li>Texts, unicode, decoding errors, regex, time series, etc.)</li>
#     </ul>
# </li>
# </ol>
# </td>
# </tr>
# </table>

# %% [markdown]
# <p style="font-size: 16px; line-height: 22px; color: #3B7EA1;">
#     Check-In:  how was last week?
# </p>

# %% [markdown]
# <hr />
# <div>
#     <p>
#         <img src="images/IntroIcon.png" style="float:left; padding:10px; width:50px; text-align:top;"/>
#         <span  style="color: #3B7EA1;font-size:24px;">Introduction</span>
#     </p>
# </div>

# %% [markdown]
# <hr />
# <h1 style="font-size:36; color: #003262;">
# Week 5 Topics</h1>
# <p>
# <ol>
#     <li>Functions &amp; passing arguments</li>
#     <li>Several ways of Handling Errors
#         <ul>
#             <li>assert</li>
#             <li>recording errors</li>
#             <li>try/except</li>
#             <li><i>Optional: *arg and **kwarg</i></li>
#             <li>Scope of variables: global, local </li>
#         </ul>
#         </li>
#     <li>System Arguments: <i>Scripts &amp; passing arguments</i> to scripts <code style="font-size:10px;">sys.argv[]</code></li>
#     <li>Lambda functions; <code>map()</code></li>
#     <li>Recursion</li>
#     </ol>
#     </hr >
# <h2 style="color:#3B7EA1;">Appendix:  Examples, How-to Demos</h2>
#     <ul>
#         <li>Logging</li>
#         <li>Global and Local; Information Hiding</li>
#         <li>Lambda Examples; Map(); Review</li>
#     </ul>
# <h2 style="color:#C4820E;">Longer reviews and example - check out during class or after as how-to guides.</h2>
#     <ol>
#         <li><a href="week_5_howtos.ipynb" target="new">Detailed How-To Guide to Lambdas</a></li>
#         <li><a href="week_05_functions_intro_extra.ipynb" target="new">Lambdas, iterators, and more</a></li>
#     <li><a target='new' href="Week-05-ApplicationDemo.ipynb">Content Aggregator</a></li>
#     </ol>

# %% [markdown]
# <hr />
# <h2 style="background-color: #003262; color:white; border-radius: 4px; padding: 8px;">
#     Functions &amp; Arguments (parameters)
# </h2>
# <ol>
#     <li>Define a function with the keyword def: <code>def</code></li>
#     <li>Pass zero or more parameters to that function; the parameters are used in the function with scope limited only to that function,<br />
# <code>def funcx():
# def funcy(a, b):
# def funcz(a, b, z = 20):</code> a default value passed last</li>
#     <li>functions may look outside themselves if you refer to a variable that is not inside the function; for instance, if there’s a global variable</li>
# <li>functions may (but don’t have to) return a new value</li>
#     <li>functions are defined - but not used until called in the code</li></ol>
# <p>Plan your project (as demo’d last week) and turn those modules into functions (or later, objects).</p>

# %% [markdown]
# <p>
# <img src="images/hands-on.png" style="float:left; padding:10px; width:100px;"/>
# <span style="color: #3B7EA1;font-size:18px;">Hands On ...</span>
#     <br /><span style="font-size:12px;">Write the same function for the weather, one with no parameters, one with two.</span>
# </p>
# <p style="color:black; font-size: 14px;"><b>Desired output</b>:</p>
# <code>The weather today is great!
# Thursday's weather will be 75 degrees.</code>

# %%
# %%html
# <button style="background-color:rgb(129,156,19);color:white;" onclick="loadDoc('answers/w5_1.txt', '1')">Show Answer</button>
# <p id="showNotes1"></p>
# Out:
# <button style="background-color:rgb(129,156,19);color:white;" onclick="loadDoc('answers/w5_1.txt', '1')">Show Answer</button>
# <p id="showNotes1"></p>

# %% [markdown]
# <hr />
# <h2>System Arguments <code>sysv.arg</code></h2>
# <p>Just as we can pass data into a function, so we can pass data from the terminal into our scripts, using sys.argv</p><p>
# Executing a .py file from the terminal window means we can provide data to the script from outside that script. The syntax to start a python program also accepts data that are read once the program starts. These are called the argument vector; in code they’re a Python list (called argv) from the system module (sys). Hence sys.argv.</p>
# <p>What is the value of <code>sys.argv[0]</code>?</p>
# <table width="100%">
#     <tr>
#         <td width="50%" style="text-align:top;">
#             <img src="images/argv.png"/>
#         </td>
#         <td style="text-align: left;">
# <pre>
# # just demo: don't execute in the notebook.
# # use the argdemo.py from terminal window.
#
# import sys
#
# print("Name of the script", sys.argv[0])
#
# print("# of args: ", len(sys.argv))
# print("arguments: ", str(sys.argv))
#
# # cat is choice
# for i in range(0, len(sys.argv)):
#     print("\t ",i," is ", sys.argv[i])
#     cat = sys.argv[3]
#
# print(cat)
# </pre>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <hr />
# <h2 style="background-color: #003262; color:white; border-radius: 4px; padding: 8px;">
# Calling, Nesting
# </h2>

# %% [markdown]
# <p>
# A rule-of-thumb is to write all the functions first, then call them as needed in the code.  In this example, the first function takes 0 parameters, the second takes 2, the third takes two, the last of which has a default value.  Note, too, that one function is <b>nested</b> inside another function.  The return value of the nested function is streamed as a parameter to the enclosing function.  For example:</p>
# <p style="font-family: Courier;">
# import statements<br /><br />
# def <span style="color:red;">function_a()</span>:<br />
# &nbsp;&nbsp;&nbsp;<i>do something</i><br /><br />
#     def <span style="color:maroon;">function_b(argument_1, argument_2)</span>:<br />
# &nbsp;&nbsp;&nbsp;<i>do something<br />
# &nbsp;&nbsp;&nbsp;return r</i><br />
# <br />
# def <span style="color:purple;">function_c(argument_1, default = "d")</span>:<br />
# &nbsp;&nbsp;&nbsp;<i>do something</i><br />
#     &nbsp;&nbsp;&nbsp;return <i>value</i><br />
# <br />
# if __name__ == "__main__":<br />
#     &nbsp;&nbsp;&nbsp;<span style="color:maroon;">function_b( 5, 25 )</span><br />
#     &nbsp;&nbsp;&nbsp;<span style='color:red;'>function_a</span>( <span style='color:purple'>function_c('a', 'b')</span> )
# </p>

# %% [markdown]
# <hr />
# <h2 style="background-color: #003262; color:white; border-radius: 4px; padding: 8px;">
# Namespaces: global and local
# </h2>

# %% [markdown]
# <p><b>Global</b> namespace contains the variables that are visible throughout the running of the program, by all parts of the program.</p>
# <p><b>Local</b> namespace is restricted to the body of a function.</p>
# <p>In this example, identify the global &amp; local variables&rsquo; values and whether they can be altered.</p>
# <p>This is called the <b>scope</b> of the variable.  Python tried to find the variables starting <b>local</b>, then <b>enclosing or nested</b>, then python searches the <b>global</b> namespace, and finally for any <b>built-in</b> vars (using <code>dir(__builtins__)</code>), called the LEGB rule.</p>
# <p><b>information hiding</b> is when a function is defined <i>within</i> another function.</p>
# <pre>
# i = 5
# j = 'test'
#
# print(i)
#
# def function_a():
#     return i + 5
# </pre>

# %%
i = 5
j = 'This is a global var from line 2.'

print(f"Start: i = {i}")

def function_a():
    print(f"\tInside function_a: GLOBAL i = {i}")
    
def function_b():
    i = 22
    print(f"\tfunction_b with LOCAL i = {i}")

def function_c(i):
    i = i + 7
    print(f"\t\tfunction_c with i parameter + local value added = {i}")
    return i

def function_d(i):
    i = i + 5
    print(f"\tfunction_d with i parameter = {i}")
    return i

def function_e(i):
    print(f"\tfunction e: {i ** 2}")

function_a()
function_b()
function_c(i)
i = function_d(i)
          
function_e(function_c(3)) # notice 3 is passed to c(); 7 is added = 10;
                          # then e squares the returned value of 10.

print(f"\n what about the other global j? {j}")
print(f"\nEnd GLOBAL i = {i}")
# Out:
# Start: i = 5
# 	Inside function_a: GLOBAL i = 5
# 	function_b with LOCAL i = 22
# 		function_c with i parameter + local value added = 12
# 	function_d with i parameter = 10
# 		function_c with i parameter + local value added = 10
# 	function e: 100
#
#  what about the other global j? This is a global var from line 2.
#
# End GLOBAL i = 10

# %%
# information hiding example
x = 'cat'

def A():
    x = 50
    print("This is A")
    
    def B(x):
        x = x + 5
        print("This is B inside A: ", x)
    # --------
    B(52)
    #B()

# ---------------------------------
A()
# Out:
# This is A
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 16
#      13     B()
#      15 # ---------------------------------
# ---> 16 A()
#
# Cell In[2], line 13, in A()
#      10     print("This is B inside A: ", x)
#      11 # --------
#      12 #B(52)
# ---> 13 B()
#
# TypeError: A.<locals>.B() missing 1 required positional argument: 'x'

# %%
# but can we access B() directly, without A()?
B(22)

# no, we can't!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # but can we access B() directly, without A()?
# ----> 2 B(22)
#       4 # no, we can't!
#
# NameError: name 'B' is not defined

# %% [markdown]
# <h2>Optional ... </h2>
# <p>Stack memory is a sort of memory allocation that the OS continuously manages and uses to store local variables in a LIFO order.
#     <img style="float:right;" src="images/HOY4C.png">On the other hand, heap memory is a type of dynamic memory allocation used for storing objects and data structures that require a longer lifespan than stack memory.
# </p>

# %% [markdown]
# <hr />
# <h2 style="background-color: #003262; color:white; border-radius: 4px; padding: 8px;">
# Recursion
# </h2>
# <p>Recursion is a function that calls itself.  Sometimes recursion consumes a lot of resources.  Python imposes a limit on the # of recursive calls; you can reset the value.  Here we compare two similar activities using recursion and separate functions.</p>

# %%
def func(x):
    return x * 2

def demo_0(limit):
    i = 0
    x = 1
    while i < limit:
        x += func(1)
        i += 1
        print(f"{i} \t {x}")
        
demo_0(10)
# Out:
# 1 	 3
# 2 	 5
# 3 	 7
# 4 	 9
# 5 	 11
# 6 	 13
# 7 	 15
# 8 	 17
# 9 	 19
# 10 	 21

# %%
# NON recursive
def func(x):
    if x > 0:
        x = x + 1
    else:
        x = 0
    return x
    
def demo_1(limit):
    cnt = 0
    i = 1
    while cnt < limit:
        i = func(i) + i
        print(f"Count: {cnt} \ti = {i}")
        cnt = cnt + 1
        
demo_1(10)
# Out:
# Count: 0 	i = 3
# Count: 1 	i = 7
# Count: 2 	i = 15
# Count: 3 	i = 31
# Count: 4 	i = 63
# Count: 5 	i = 127
# Count: 6 	i = 255
# Count: 7 	i = 511
# Count: 8 	i = 1023
# Count: 9 	i = 2047

# %%
# Recursive
cnt = 1

def rec_1(x):
    """ a recursive function that accepts a single int value """
    global cnt
    if x > 0:
        x = x + rec_1(x - 1)
        print(f"Count: {cnt} \tx = {x}")
        cnt = cnt + 1
    else:
        x = 0
    return x
    
print("-"*30)
rec_1(10)
# Out:
# ------------------------------
# Count: 1 	x = 1
# Count: 2 	x = 3
# Count: 3 	x = 6
# Count: 4 	x = 10
# Count: 5 	x = 15
# Count: 6 	x = 21
# Count: 7 	x = 28
# Count: 8 	x = 36
# Count: 9 	x = 45
# Count: 10 	x = 55
# 55

# %% [markdown]
# <p><b style="color: #3B7EA1;">Sometime recursion is <i>not</i> faster...</p>

# %%
import time

start = time.time()

rec_1(2000)

print(time.time() - start)
# Out:
# Count: 11 	x = 1
# Count: 12 	x = 3
# Count: 13 	x = 6
# Count: 14 	x = 10
# Count: 15 	x = 15
# Count: 16 	x = 21
# Count: 17 	x = 28
# Count: 18 	x = 36
# Count: 19 	x = 45
# Count: 20 	x = 55
# Count: 21 	x = 66
# Count: 22 	x = 78
# Count: 23 	x = 91
# Count: 24 	x = 105
# Count: 25 	x = 120
# Count: 26 	x = 136
# Count: 27 	x = 153
# Count: 28 	x = 171
# Count: 29 	x = 190
# Count: 30 	x = 210
# Count: 31 	x = 231
# Count: 32 	x = 253
# Count: 33 	x = 276
# Count: 34 	x = 300
# Count: 35 	x = 325
# Count: 36 	x = 351
# Count: 37 	x = 378
# Count: 38 	x = 406
# Count: 39 	x = 435
# Count: 40 	x = 465
# Count: 41 	x = 496
# Count: 42 	x = 528
# Count: 43 	x = 561
# Count: 44 	x = 595
# Count: 45 	x = 630
# Count: 46 	x = 666
# Count: 47 	x = 703
# Count: 48 	x = 741
# Count: 49 	x = 780
# Count: 50 	x = 820
# Count: 51 	x = 861
# Count: 52 	x = 903
# Count: 53 	x = 946
# Count: 54 	x = 990
# Count: 55 	x = 1035
# Count: 56 	x = 1081
# Count: 57 	x = 1128
# Count: 58 	x = 1176
# Count: 59 	x = 1225
# Count: 60 	x = 1275
# Count: 61 	x = 1326
# Count: 62 	x = 1378
# Count: 63 	x = 1431
# Count: 64 	x = 1485
# Count: 65 	x = 1540
# Count: 66 	x = 1596
# Count: 67 	x = 1653
# Count: 68 	x = 1711
# Count: 69 	x = 1770
# Count: 70 	x = 1830
# Count: 71 	x = 1891
# Count: 72 	x = 1953
# Count: 73 	x = 2016
# Count: 74 	x = 2080
# Count: 75 	x = 2145
# Count: 76 	x = 2211
# Count: 77 	x = 2278
# Count: 78 	x = 2346
# Count: 79 	x = 2415
# Count: 80 	x = 2485
# Count: 81 	x = 2556
# Count: 82 	x = 2628
# Count: 83 	x = 2701
# Count: 84 	x = 2775
# Count: 85 	x = 2850
# Count: 86 	x = 2926
# Count: 87 	x = 3003
# Count: 88 	x = 3081
# Count: 89 	x = 3160
# Count: 90 	x = 3240
# Count: 91 	x = 3321
# Count: 92 	x = 3403
# Count: 93 	x = 3486
# Count: 94 	x = 3570
# Count: 95 	x = 3655
# Count: 96 	x = 3741
# Count: 97 	x = 3828
# Count: 98 	x = 3916
# Count: 99 	x = 4005
# Count: 100 	x = 4095
# Count: 101 	x = 4186
# Count: 102 	x = 4278
# Count: 103 	x = 4371
# Count: 104 	x = 4465
# Count: 105 	x = 4560
# Count: 106 	x = 4656
# Count: 107 	x = 4753
# Count: 108 	x = 4851
# Count: 109 	x = 4950
# Count: 110 	x = 5050
# Count: 111 	x = 5151
# Count: 112 	x = 5253
# Count: 113 	x = 5356
# Count: 114 	x = 5460
# Count: 115 	x = 5565
# Count: 116 	x = 5671
# Count: 117 	x = 5778
# Count: 118 	x = 5886
# Count: 119 	x = 5995
# Count: 120 	x = 6105
# Count: 121 	x = 6216
# Count: 122 	x = 6328
# Count: 123 	x = 6441
# Count: 124 	x = 6555
# Count: 125 	x = 6670
# Count: 126 	x = 6786
# Count: 127 	x = 6903
# Count: 128 	x = 7021
# Count: 129 	x = 7140
# Count: 130 	x = 7260
# Count: 131 	x = 7381
# Count: 132 	x = 7503
# Count: 133 	x = 7626
# Count: 134 	x = 7750
# Count: 135 	x = 7875
# Count: 136 	x = 8001
# Count: 137 	x = 8128
# Count: 138 	x = 8256
# Count: 139 	x = 8385
# Count: 140 	x = 8515
# Count: 141 	x = 8646
# Count: 142 	x = 8778
# Count: 143 	x = 8911
# Count: 144 	x = 9045
# Count: 145 	x = 9180
# Count: 146 	x = 9316
# Count: 147 	x = 9453
# Count: 148 	x = 9591
# Count: 149 	x = 9730
# Count: 150 	x = 9870
# Count: 151 	x = 10011
# Count: 152 	x = 10153
# Count: 153 	x = 10296
# Count: 154 	x = 10440
# Count: 155 	x = 10585
# Count: 156 	x = 10731
# Count: 157 	x = 10878
# Count: 158 	x = 11026
# Count: 159 	x = 11175
# Count: 160 	x = 11325
# Count: 161 	x = 11476
# Count: 162 	x = 11628
# Count: 163 	x = 11781
# Count: 164 	x = 11935
# Count: 165 	x = 12090
# Count: 166 	x = 12246
# Count: 167 	x = 12403
# Count: 168 	x = 12561
# Count: 169 	x = 12720
# Count: 170 	x = 12880
# Count: 171 	x = 13041
# Count: 172 	x = 13203
# Count: 173 	x = 13366
# Count: 174 	x = 13530
# Count: 175 	x = 13695
# Count: 176 	x = 13861
# Count: 177 	x = 14028
# Count: 178 	x = 14196
# Count: 179 	x = 14365
# Count: 180 	x = 14535
# Count: 181 	x = 14706
# Count: 182 	x = 14878
# Count: 183 	x = 15051
# Count: 184 	x = 15225
# Count: 185 	x = 15400
# Count: 186 	x = 15576
# Count: 187 	x = 15753
# Count: 188 	x = 15931
# Count: 189 	x = 16110
# Count: 190 	x = 16290
# Count: 191 	x = 16471
# Count: 192 	x = 16653
# Count: 193 	x = 16836
# Count: 194 	x = 17020
# Count: 195 	x = 17205
# Count: 196 	x = 17391
# Count: 197 	x = 17578
# Count: 198 	x = 17766
# Count: 199 	x = 17955
# Count: 200 	x = 18145
# Count: 201 	x = 18336
# Count: 202 	x = 18528
# Count: 203 	x = 18721
# Count: 204 	x = 18915
# Count: 205 	x = 19110
# Count: 206 	x = 19306
# Count: 207 	x = 19503
# Count: 208 	x = 19701
# Count: 209 	x = 19900
# Count: 210 	x = 20100
# Count: 211 	x = 20301
# Count: 212 	x = 20503
# Count: 213 	x = 20706
# Count: 214 	x = 20910
# Count: 215 	x = 21115
# Count: 216 	x = 21321
# Count: 217 	x = 21528
# Count: 218 	x = 21736
# Count: 219 	x = 21945
# Count: 220 	x = 22155
# Count: 221 	x = 22366
# Count: 222 	x = 22578
# Count: 223 	x = 22791
# Count: 224 	x = 23005
# Count: 225 	x = 23220
# Count: 226 	x = 23436
# Count: 227 	x = 23653
# Count: 228 	x = 23871
# Count: 229 	x = 24090
# Count: 230 	x = 24310
# Count: 231 	x = 24531
# Count: 232 	x = 24753
# Count: 233 	x = 24976
# Count: 234 	x = 25200
# Count: 235 	x = 25425
# Count: 236 	x = 25651
# Count: 237 	x = 25878
# Count: 238 	x = 26106
# Count: 239 	x = 26335
# Count: 240 	x = 26565
# Count: 241 	x = 26796
# Count: 242 	x = 27028
# Count: 243 	x = 27261
# Count: 244 	x = 27495
# Count: 245 	x = 27730
# Count: 246 	x = 27966
# Count: 247 	x = 28203
# Count: 248 	x = 28441
# Count: 249 	x = 28680
# Count: 250 	x = 28920
# Count: 251 	x = 29161
# Count: 252 	x = 29403
# Count: 253 	x = 29646
# Count: 254 	x = 29890
# Count: 255 	x = 30135
# Count: 256 	x = 30381
# Count: 257 	x = 30628
# Count: 258 	x = 30876
# Count: 259 	x = 31125
# Count: 260 	x = 31375
# Count: 261 	x = 31626
# Count: 262 	x = 31878
# Count: 263 	x = 32131
# Count: 264 	x = 32385
# Count: 265 	x = 32640
# Count: 266 	x = 32896
# Count: 267 	x = 33153
# Count: 268 	x = 33411
# Count: 269 	x = 33670
# Count: 270 	x = 33930
# Count: 271 	x = 34191
# Count: 272 	x = 34453
# Count: 273 	x = 34716
# Count: 274 	x = 34980
# Count: 275 	x = 35245
# Count: 276 	x = 35511
# Count: 277 	x = 35778
# Count: 278 	x = 36046
# Count: 279 	x = 36315
# Count: 280 	x = 36585
# Count: 281 	x = 36856
# Count: 282 	x = 37128
# Count: 283 	x = 37401
# Count: 284 	x = 37675
# Count: 285 	x = 37950
# Count: 286 	x = 38226
# Count: 287 	x = 38503
# Count: 288 	x = 38781
# Count: 289 	x = 39060
# Count: 290 	x = 39340
# Count: 291 	x = 39621
# Count: 292 	x = 39903
# Count: 293 	x = 40186
# Count: 294 	x = 40470
# Count: 295 	x = 40755
# Count: 296 	x = 41041
# Count: 297 	x = 41328
# Count: 298 	x = 41616
# Count: 299 	x = 41905
# Count: 300 	x = 42195
# Count: 301 	x = 42486
# Count: 302 	x = 42778
# Count: 303 	x = 43071
# Count: 304 	x = 43365
# Count: 305 	x = 43660
# Count: 306 	x = 43956
# Count: 307 	x = 44253
# Count: 308 	x = 44551
# Count: 309 	x = 44850
# Count: 310 	x = 45150
# Count: 311 	x = 45451
# Count: 312 	x = 45753
# Count: 313 	x = 46056
# Count: 314 	x = 46360
# Count: 315 	x = 46665
# Count: 316 	x = 46971
# Count: 317 	x = 47278
# Count: 318 	x = 47586
# Count: 319 	x = 47895
# Count: 320 	x = 48205
# Count: 321 	x = 48516
# Count: 322 	x = 48828
# Count: 323 	x = 49141
# Count: 324 	x = 49455
# Count: 325 	x = 49770
# Count: 326 	x = 50086
# Count: 327 	x = 50403
# Count: 328 	x = 50721
# Count: 329 	x = 51040
# Count: 330 	x = 51360
# Count: 331 	x = 51681
# Count: 332 	x = 52003
# Count: 333 	x = 52326
# Count: 334 	x = 52650
# Count: 335 	x = 52975
# Count: 336 	x = 53301
# Count: 337 	x = 53628
# Count: 338 	x = 53956
# Count: 339 	x = 54285
# Count: 340 	x = 54615
# Count: 341 	x = 54946
# Count: 342 	x = 55278
# Count: 343 	x = 55611
# Count: 344 	x = 55945
# Count: 345 	x = 56280
# Count: 346 	x = 56616
# Count: 347 	x = 56953
# Count: 348 	x = 57291
# Count: 349 	x = 57630
# Count: 350 	x = 57970
# Count: 351 	x = 58311
# Count: 352 	x = 58653
# Count: 353 	x = 58996
# Count: 354 	x = 59340
# Count: 355 	x = 59685
# Count: 356 	x = 60031
# Count: 357 	x = 60378
# Count: 358 	x = 60726
# Count: 359 	x = 61075
# Count: 360 	x = 61425
# Count: 361 	x = 61776
# Count: 362 	x = 62128
# Count: 363 	x = 62481
# Count: 364 	x = 62835
# Count: 365 	x = 63190
# Count: 366 	x = 63546
# Count: 367 	x = 63903
# Count: 368 	x = 64261
# Count: 369 	x = 64620
# Count: 370 	x = 64980
# Count: 371 	x = 65341
# Count: 372 	x = 65703
# Count: 373 	x = 66066
# Count: 374 	x = 66430
# Count: 375 	x = 66795
# Count: 376 	x = 67161
# Count: 377 	x = 67528
# Count: 378 	x = 67896
# Count: 379 	x = 68265
# Count: 380 	x = 68635
# Count: 381 	x = 69006
# Count: 382 	x = 69378
# Count: 383 	x = 69751
# Count: 384 	x = 70125
# Count: 385 	x = 70500
# Count: 386 	x = 70876
# Count: 387 	x = 71253
# Count: 388 	x = 71631
# Count: 389 	x = 72010
# Count: 390 	x = 72390
# Count: 391 	x = 72771
# Count: 392 	x = 73153
# Count: 393 	x = 73536
# Count: 394 	x = 73920
# Count: 395 	x = 74305
# Count: 396 	x = 74691
# Count: 397 	x = 75078
# Count: 398 	x = 75466
# Count: 399 	x = 75855
# Count: 400 	x = 76245
# Count: 401 	x = 76636
# Count: 402 	x = 77028
# Count: 403 	x = 77421
# Count: 404 	x = 77815
# Count: 405 	x = 78210
# Count: 406 	x = 78606
# Count: 407 	x = 79003
# Count: 408 	x = 79401
# Count: 409 	x = 79800
# Count: 410 	x = 80200
# Count: 411 	x = 80601
# Count: 412 	x = 81003
# Count: 413 	x = 81406
# Count: 414 	x = 81810
# Count: 415 	x = 82215
# Count: 416 	x = 82621
# Count: 417 	x = 83028
# Count: 418 	x = 83436
# Count: 419 	x = 83845
# Count: 420 	x = 84255
# Count: 421 	x = 84666
# Count: 422 	x = 85078
# Count: 423 	x = 85491
# Count: 424 	x = 85905
# Count: 425 	x = 86320
# Count: 426 	x = 86736
# Count: 427 	x = 87153
# Count: 428 	x = 87571
# Count: 429 	x = 87990
# Count: 430 	x = 88410
# Count: 431 	x = 88831
# Count: 432 	x = 89253
# Count: 433 	x = 89676
# Count: 434 	x = 90100
# Count: 435 	x = 90525
# Count: 436 	x = 90951
# Count: 437 	x = 91378
# Count: 438 	x = 91806
# Count: 439 	x = 92235
# Count: 440 	x = 92665
# Count: 441 	x = 93096
# Count: 442 	x = 93528
# Count: 443 	x = 93961
# Count: 444 	x = 94395
# Count: 445 	x = 94830
# Count: 446 	x = 95266
# Count: 447 	x = 95703
# Count: 448 	x = 96141
# Count: 449 	x = 96580
# Count: 450 	x = 97020
# Count: 451 	x = 97461
# Count: 452 	x = 97903
# Count: 453 	x = 98346
# Count: 454 	x = 98790
# Count: 455 	x = 99235
# Count: 456 	x = 99681
# Count: 457 	x = 100128
# Count: 458 	x = 100576
# Count: 459 	x = 101025
# Count: 460 	x = 101475
# Count: 461 	x = 101926
# Count: 462 	x = 102378
# Count: 463 	x = 102831
# Count: 464 	x = 103285
# Count: 465 	x = 103740
# Count: 466 	x = 104196
# Count: 467 	x = 104653
# Count: 468 	x = 105111
# Count: 469 	x = 105570
# Count: 470 	x = 106030
# Count: 471 	x = 106491
# Count: 472 	x = 106953
# Count: 473 	x = 107416
# Count: 474 	x = 107880
# Count: 475 	x = 108345
# Count: 476 	x = 108811
# Count: 477 	x = 109278
# Count: 478 	x = 109746
# Count: 479 	x = 110215
# Count: 480 	x = 110685
# Count: 481 	x = 111156
# Count: 482 	x = 111628
# Count: 483 	x = 112101
# Count: 484 	x = 112575
# Count: 485 	x = 113050
# Count: 486 	x = 113526
# Count: 487 	x = 114003
# Count: 488 	x = 114481
# Count: 489 	x = 114960
# Count: 490 	x = 115440
# Count: 491 	x = 115921
# Count: 492 	x = 116403
# Count: 493 	x = 116886
# Count: 494 	x = 117370
# Count: 495 	x = 117855
# Count: 496 	x = 118341
# Count: 497 	x = 118828
# Count: 498 	x = 119316
# Count: 499 	x = 119805
# Count: 500 	x = 120295
# Count: 501 	x = 120786
# Count: 502 	x = 121278
# Count: 503 	x = 121771
# Count: 504 	x = 122265
# Count: 505 	x = 122760
# Count: 506 	x = 123256
# Count: 507 	x = 123753
# Count: 508 	x = 124251
# Count: 509 	x = 124750
# Count: 510 	x = 125250
# Count: 511 	x = 125751
# Count: 512 	x = 126253
# Count: 513 	x = 126756
# Count: 514 	x = 127260
# Count: 515 	x = 127765
# Count: 516 	x = 128271
# Count: 517 	x = 128778
# Count: 518 	x = 129286
# Count: 519 	x = 129795
# Count: 520 	x = 130305
# Count: 521 	x = 130816
# Count: 522 	x = 131328
# Count: 523 	x = 131841
# Count: 524 	x = 132355
# Count: 525 	x = 132870
# Count: 526 	x = 133386
# Count: 527 	x = 133903
# Count: 528 	x = 134421
# Count: 529 	x = 134940
# Count: 530 	x = 135460
# Count: 531 	x = 135981
# Count: 532 	x = 136503
# Count: 533 	x = 137026
# Count: 534 	x = 137550
# Count: 535 	x = 138075
# Count: 536 	x = 138601
# Count: 537 	x = 139128
# Count: 538 	x = 139656
# Count: 539 	x = 140185
# Count: 540 	x = 140715
# Count: 541 	x = 141246
# Count: 542 	x = 141778
# Count: 543 	x = 142311
# Count: 544 	x = 142845
# Count: 545 	x = 143380
# Count: 546 	x = 143916
# Count: 547 	x = 144453
# Count: 548 	x = 144991
# Count: 549 	x = 145530
# Count: 550 	x = 146070
# Count: 551 	x = 146611
# Count: 552 	x = 147153
# Count: 553 	x = 147696
# Count: 554 	x = 148240
# Count: 555 	x = 148785
# Count: 556 	x = 149331
# Count: 557 	x = 149878
# Count: 558 	x = 150426
# Count: 559 	x = 150975
# Count: 560 	x = 151525
# Count: 561 	x = 152076
# Count: 562 	x = 152628
# Count: 563 	x = 153181
# Count: 564 	x = 153735
# Count: 565 	x = 154290
# Count: 566 	x = 154846
# Count: 567 	x = 155403
# Count: 568 	x = 155961
# Count: 569 	x = 156520
# Count: 570 	x = 157080
# Count: 571 	x = 157641
# Count: 572 	x = 158203
# Count: 573 	x = 158766
# Count: 574 	x = 159330
# Count: 575 	x = 159895
# Count: 576 	x = 160461
# Count: 577 	x = 161028
# Count: 578 	x = 161596
# Count: 579 	x = 162165
# Count: 580 	x = 162735
# Count: 581 	x = 163306
# Count: 582 	x = 163878
# Count: 583 	x = 164451
# Count: 584 	x = 165025
# Count: 585 	x = 165600
# Count: 586 	x = 166176
# Count: 587 	x = 166753
# Count: 588 	x = 167331
# Count: 589 	x = 167910
# Count: 590 	x = 168490
# Count: 591 	x = 169071
# Count: 592 	x = 169653
# Count: 593 	x = 170236
# Count: 594 	x = 170820
# Count: 595 	x = 171405
# Count: 596 	x = 171991
# Count: 597 	x = 172578
# Count: 598 	x = 173166
# Count: 599 	x = 173755
# Count: 600 	x = 174345
# Count: 601 	x = 174936
# Count: 602 	x = 175528
# Count: 603 	x = 176121
# Count: 604 	x = 176715
# Count: 605 	x = 177310
# Count: 606 	x = 177906
# Count: 607 	x = 178503
# Count: 608 	x = 179101
# Count: 609 	x = 179700
# Count: 610 	x = 180300
# Count: 611 	x = 180901
# Count: 612 	x = 181503
# Count: 613 	x = 182106
# Count: 614 	x = 182710
# Count: 615 	x = 183315
# Count: 616 	x = 183921
# Count: 617 	x = 184528
# Count: 618 	x = 185136
# Count: 619 	x = 185745
# Count: 620 	x = 186355
# Count: 621 	x = 186966
# Count: 622 	x = 187578
# Count: 623 	x = 188191
# Count: 624 	x = 188805
# Count: 625 	x = 189420
# Count: 626 	x = 190036
# Count: 627 	x = 190653
# Count: 628 	x = 191271
# Count: 629 	x = 191890
# Count: 630 	x = 192510
# Count: 631 	x = 193131
# Count: 632 	x = 193753
# Count: 633 	x = 194376
# Count: 634 	x = 195000
# Count: 635 	x = 195625
# Count: 636 	x = 196251
# Count: 637 	x = 196878
# Count: 638 	x = 197506
# Count: 639 	x = 198135
# Count: 640 	x = 198765
# Count: 641 	x = 199396
# Count: 642 	x = 200028
# Count: 643 	x = 200661
# Count: 644 	x = 201295
# Count: 645 	x = 201930
# Count: 646 	x = 202566
# Count: 647 	x = 203203
# Count: 648 	x = 203841
# Count: 649 	x = 204480
# Count: 650 	x = 205120
# Count: 651 	x = 205761
# Count: 652 	x = 206403
# Count: 653 	x = 207046
# Count: 654 	x = 207690
# Count: 655 	x = 208335
# Count: 656 	x = 208981
# Count: 657 	x = 209628
# Count: 658 	x = 210276
# Count: 659 	x = 210925
# Count: 660 	x = 211575
# Count: 661 	x = 212226
# Count: 662 	x = 212878
# Count: 663 	x = 213531
# Count: 664 	x = 214185
# Count: 665 	x = 214840
# Count: 666 	x = 215496
# Count: 667 	x = 216153
# Count: 668 	x = 216811
# Count: 669 	x = 217470
# Count: 670 	x = 218130
# Count: 671 	x = 218791
# Count: 672 	x = 219453
# Count: 673 	x = 220116
# Count: 674 	x = 220780
# Count: 675 	x = 221445
# Count: 676 	x = 222111
# Count: 677 	x = 222778
# Count: 678 	x = 223446
# Count: 679 	x = 224115
# Count: 680 	x = 224785
# Count: 681 	x = 225456
# Count: 682 	x = 226128
# Count: 683 	x = 226801
# Count: 684 	x = 227475
# Count: 685 	x = 228150
# Count: 686 	x = 228826
# Count: 687 	x = 229503
# Count: 688 	x = 230181
# Count: 689 	x = 230860
# Count: 690 	x = 231540
# Count: 691 	x = 232221
# Count: 692 	x = 232903
# Count: 693 	x = 233586
# Count: 694 	x = 234270
# Count: 695 	x = 234955
# Count: 696 	x = 235641
# Count: 697 	x = 236328
# Count: 698 	x = 237016
# Count: 699 	x = 237705
# Count: 700 	x = 238395
# Count: 701 	x = 239086
# Count: 702 	x = 239778
# Count: 703 	x = 240471
# Count: 704 	x = 241165
# Count: 705 	x = 241860
# Count: 706 	x = 242556
# Count: 707 	x = 243253
# Count: 708 	x = 243951
# Count: 709 	x = 244650
# Count: 710 	x = 245350
# Count: 711 	x = 246051
# Count: 712 	x = 246753
# Count: 713 	x = 247456
# Count: 714 	x = 248160
# Count: 715 	x = 248865
# Count: 716 	x = 249571
# Count: 717 	x = 250278
# Count: 718 	x = 250986
# Count: 719 	x = 251695
# Count: 720 	x = 252405
# Count: 721 	x = 253116
# Count: 722 	x = 253828
# Count: 723 	x = 254541
# Count: 724 	x = 255255
# Count: 725 	x = 255970
# Count: 726 	x = 256686
# Count: 727 	x = 257403
# Count: 728 	x = 258121
# Count: 729 	x = 258840
# Count: 730 	x = 259560
# Count: 731 	x = 260281
# Count: 732 	x = 261003
# Count: 733 	x = 261726
# Count: 734 	x = 262450
# Count: 735 	x = 263175
# Count: 736 	x = 263901
# Count: 737 	x = 264628
# Count: 738 	x = 265356
# Count: 739 	x = 266085
# Count: 740 	x = 266815
# Count: 741 	x = 267546
# Count: 742 	x = 268278
# Count: 743 	x = 269011
# Count: 744 	x = 269745
# Count: 745 	x = 270480
# Count: 746 	x = 271216
# Count: 747 	x = 271953
# Count: 748 	x = 272691
# Count: 749 	x = 273430
# Count: 750 	x = 274170
# Count: 751 	x = 274911
# Count: 752 	x = 275653
# Count: 753 	x = 276396
# Count: 754 	x = 277140
# Count: 755 	x = 277885
# Count: 756 	x = 278631
# Count: 757 	x = 279378
# Count: 758 	x = 280126
# Count: 759 	x = 280875
# Count: 760 	x = 281625
# Count: 761 	x = 282376
# Count: 762 	x = 283128
# Count: 763 	x = 283881
# Count: 764 	x = 284635
# Count: 765 	x = 285390
# Count: 766 	x = 286146
# Count: 767 	x = 286903
# Count: 768 	x = 287661
# Count: 769 	x = 288420
# Count: 770 	x = 289180
# Count: 771 	x = 289941
# Count: 772 	x = 290703
# Count: 773 	x = 291466
# Count: 774 	x = 292230
# Count: 775 	x = 292995
# Count: 776 	x = 293761
# Count: 777 	x = 294528
# Count: 778 	x = 295296
# Count: 779 	x = 296065
# Count: 780 	x = 296835
# Count: 781 	x = 297606
# Count: 782 	x = 298378
# Count: 783 	x = 299151
# Count: 784 	x = 299925
# Count: 785 	x = 300700
# Count: 786 	x = 301476
# Count: 787 	x = 302253
# Count: 788 	x = 303031
# Count: 789 	x = 303810
# Count: 790 	x = 304590
# Count: 791 	x = 305371
# Count: 792 	x = 306153
# Count: 793 	x = 306936
# Count: 794 	x = 307720
# Count: 795 	x = 308505
# Count: 796 	x = 309291
# Count: 797 	x = 310078
# Count: 798 	x = 310866
# Count: 799 	x = 311655
# Count: 800 	x = 312445
# Count: 801 	x = 313236
# Count: 802 	x = 314028
# Count: 803 	x = 314821
# Count: 804 	x = 315615
# Count: 805 	x = 316410
# Count: 806 	x = 317206
# Count: 807 	x = 318003
# Count: 808 	x = 318801
# Count: 809 	x = 319600
# Count: 810 	x = 320400
# Count: 811 	x = 321201
# Count: 812 	x = 322003
# Count: 813 	x = 322806
# Count: 814 	x = 323610
# Count: 815 	x = 324415
# Count: 816 	x = 325221
# Count: 817 	x = 326028
# Count: 818 	x = 326836
# Count: 819 	x = 327645
# Count: 820 	x = 328455
# Count: 821 	x = 329266
# Count: 822 	x = 330078
# Count: 823 	x = 330891
# Count: 824 	x = 331705
# Count: 825 	x = 332520
# Count: 826 	x = 333336
# Count: 827 	x = 334153
# Count: 828 	x = 334971
# Count: 829 	x = 335790
# Count: 830 	x = 336610
# Count: 831 	x = 337431
# Count: 832 	x = 338253
# Count: 833 	x = 339076
# Count: 834 	x = 339900
# Count: 835 	x = 340725
# Count: 836 	x = 341551
# Count: 837 	x = 342378
# Count: 838 	x = 343206
# Count: 839 	x = 344035
# Count: 840 	x = 344865
# Count: 841 	x = 345696
# Count: 842 	x = 346528
# Count: 843 	x = 347361
# Count: 844 	x = 348195
# Count: 845 	x = 349030
# Count: 846 	x = 349866
# Count: 847 	x = 350703
# Count: 848 	x = 351541
# Count: 849 	x = 352380
# Count: 850 	x = 353220
# Count: 851 	x = 354061
# Count: 852 	x = 354903
# Count: 853 	x = 355746
# Count: 854 	x = 356590
# Count: 855 	x = 357435
# Count: 856 	x = 358281
# Count: 857 	x = 359128
# Count: 858 	x = 359976
# Count: 859 	x = 360825
# Count: 860 	x = 361675
# Count: 861 	x = 362526
# Count: 862 	x = 363378
# Count: 863 	x = 364231
# Count: 864 	x = 365085
# Count: 865 	x = 365940
# Count: 866 	x = 366796
# Count: 867 	x = 367653
# Count: 868 	x = 368511
# Count: 869 	x = 369370
# Count: 870 	x = 370230
# Count: 871 	x = 371091
# Count: 872 	x = 371953
# Count: 873 	x = 372816
# Count: 874 	x = 373680
# Count: 875 	x = 374545
# Count: 876 	x = 375411
# Count: 877 	x = 376278
# Count: 878 	x = 377146
# Count: 879 	x = 378015
# Count: 880 	x = 378885
# Count: 881 	x = 379756
# Count: 882 	x = 380628
# Count: 883 	x = 381501
# Count: 884 	x = 382375
# Count: 885 	x = 383250
# Count: 886 	x = 384126
# Count: 887 	x = 385003
# Count: 888 	x = 385881
# Count: 889 	x = 386760
# Count: 890 	x = 387640
# Count: 891 	x = 388521
# Count: 892 	x = 389403
# Count: 893 	x = 390286
# Count: 894 	x = 391170
# Count: 895 	x = 392055
# Count: 896 	x = 392941
# Count: 897 	x = 393828
# Count: 898 	x = 394716
# Count: 899 	x = 395605
# Count: 900 	x = 396495
# Count: 901 	x = 397386
# Count: 902 	x = 398278
# Count: 903 	x = 399171
# Count: 904 	x = 400065
# Count: 905 	x = 400960
# Count: 906 	x = 401856
# Count: 907 	x = 402753
# Count: 908 	x = 403651
# Count: 909 	x = 404550
# Count: 910 	x = 405450
# Count: 911 	x = 406351
# Count: 912 	x = 407253
# Count: 913 	x = 408156
# Count: 914 	x = 409060
# Count: 915 	x = 409965
# Count: 916 	x = 410871
# Count: 917 	x = 411778
# Count: 918 	x = 412686
# Count: 919 	x = 413595
# Count: 920 	x = 414505
# Count: 921 	x = 415416
# Count: 922 	x = 416328
# Count: 923 	x = 417241
# Count: 924 	x = 418155
# Count: 925 	x = 419070
# Count: 926 	x = 419986
# Count: 927 	x = 420903
# Count: 928 	x = 421821
# Count: 929 	x = 422740
# Count: 930 	x = 423660
# Count: 931 	x = 424581
# Count: 932 	x = 425503
# Count: 933 	x = 426426
# Count: 934 	x = 427350
# Count: 935 	x = 428275
# Count: 936 	x = 429201
# Count: 937 	x = 430128
# Count: 938 	x = 431056
# Count: 939 	x = 431985
# Count: 940 	x = 432915
# Count: 941 	x = 433846
# Count: 942 	x = 434778
# Count: 943 	x = 435711
# Count: 944 	x = 436645
# Count: 945 	x = 437580
# Count: 946 	x = 438516
# Count: 947 	x = 439453
# Count: 948 	x = 440391
# Count: 949 	x = 441330
# Count: 950 	x = 442270
# Count: 951 	x = 443211
# Count: 952 	x = 444153
# Count: 953 	x = 445096
# Count: 954 	x = 446040
# Count: 955 	x = 446985
# Count: 956 	x = 447931
# Count: 957 	x = 448878
# Count: 958 	x = 449826
# Count: 959 	x = 450775
# Count: 960 	x = 451725
# Count: 961 	x = 452676
# Count: 962 	x = 453628
# Count: 963 	x = 454581
# Count: 964 	x = 455535
# Count: 965 	x = 456490
# Count: 966 	x = 457446
# Count: 967 	x = 458403
# Count: 968 	x = 459361
# Count: 969 	x = 460320
# Count: 970 	x = 461280
# Count: 971 	x = 462241
# Count: 972 	x = 463203
# Count: 973 	x = 464166
# Count: 974 	x = 465130
# Count: 975 	x = 466095
# Count: 976 	x = 467061
# Count: 977 	x = 468028
# Count: 978 	x = 468996
# Count: 979 	x = 469965
# Count: 980 	x = 470935
# Count: 981 	x = 471906
# Count: 982 	x = 472878
# Count: 983 	x = 473851
# Count: 984 	x = 474825
# Count: 985 	x = 475800
# Count: 986 	x = 476776
# Count: 987 	x = 477753
# Count: 988 	x = 478731
# Count: 989 	x = 479710
# Count: 990 	x = 480690
# Count: 991 	x = 481671
# Count: 992 	x = 482653
# Count: 993 	x = 483636
# Count: 994 	x = 484620
# Count: 995 	x = 485605
# Count: 996 	x = 486591
# Count: 997 	x = 487578
# Count: 998 	x = 488566
# Count: 999 	x = 489555
# Count: 1000 	x = 490545
# Count: 1001 	x = 491536
# Count: 1002 	x = 492528
# Count: 1003 	x = 493521
# Count: 1004 	x = 494515
# Count: 1005 	x = 495510
# Count: 1006 	x = 496506
# Count: 1007 	x = 497503
# Count: 1008 	x = 498501
# Count: 1009 	x = 499500
# Count: 1010 	x = 500500
# Count: 1011 	x = 501501
# Count: 1012 	x = 502503
# Count: 1013 	x = 503506
# Count: 1014 	x = 504510
# Count: 1015 	x = 505515
# Count: 1016 	x = 506521
# Count: 1017 	x = 507528
# Count: 1018 	x = 508536
# Count: 1019 	x = 509545
# Count: 1020 	x = 510555
# Count: 1021 	x = 511566
# Count: 1022 	x = 512578
# Count: 1023 	x = 513591
# Count: 1024 	x = 514605
# Count: 1025 	x = 515620
# Count: 1026 	x = 516636
# Count: 1027 	x = 517653
# Count: 1028 	x = 518671
# Count: 1029 	x = 519690
# Count: 1030 	x = 520710
# Count: 1031 	x = 521731
# Count: 1032 	x = 522753
# Count: 1033 	x = 523776
# Count: 1034 	x = 524800
# Count: 1035 	x = 525825
# Count: 1036 	x = 526851
# Count: 1037 	x = 527878
# Count: 1038 	x = 528906
# Count: 1039 	x = 529935
# Count: 1040 	x = 530965
# Count: 1041 	x = 531996
# Count: 1042 	x = 533028
# Count: 1043 	x = 534061
# Count: 1044 	x = 535095
# Count: 1045 	x = 536130
# Count: 1046 	x = 537166
# Count: 1047 	x = 538203
# Count: 1048 	x = 539241
# Count: 1049 	x = 540280
# Count: 1050 	x = 541320
# Count: 1051 	x = 542361
# Count: 1052 	x = 543403
# Count: 1053 	x = 544446
# Count: 1054 	x = 545490
# Count: 1055 	x = 546535
# Count: 1056 	x = 547581
# Count: 1057 	x = 548628
# Count: 1058 	x = 549676
# Count: 1059 	x = 550725
# Count: 1060 	x = 551775
# Count: 1061 	x = 552826
# Count: 1062 	x = 553878
# Count: 1063 	x = 554931
# Count: 1064 	x = 555985
# Count: 1065 	x = 557040
# Count: 1066 	x = 558096
# Count: 1067 	x = 559153
# Count: 1068 	x = 560211
# Count: 1069 	x = 561270
# Count: 1070 	x = 562330
# Count: 1071 	x = 563391
# Count: 1072 	x = 564453
# Count: 1073 	x = 565516
# Count: 1074 	x = 566580
# Count: 1075 	x = 567645
# Count: 1076 	x = 568711
# Count: 1077 	x = 569778
# Count: 1078 	x = 570846
# Count: 1079 	x = 571915
# Count: 1080 	x = 572985
# Count: 1081 	x = 574056
# Count: 1082 	x = 575128
# Count: 1083 	x = 576201
# Count: 1084 	x = 577275
# Count: 1085 	x = 578350
# Count: 1086 	x = 579426
# Count: 1087 	x = 580503
# Count: 1088 	x = 581581
# Count: 1089 	x = 582660
# Count: 1090 	x = 583740
# Count: 1091 	x = 584821
# Count: 1092 	x = 585903
# Count: 1093 	x = 586986
# Count: 1094 	x = 588070
# Count: 1095 	x = 589155
# Count: 1096 	x = 590241
# Count: 1097 	x = 591328
# Count: 1098 	x = 592416
# Count: 1099 	x = 593505
# Count: 1100 	x = 594595
# Count: 1101 	x = 595686
# Count: 1102 	x = 596778
# Count: 1103 	x = 597871
# Count: 1104 	x = 598965
# Count: 1105 	x = 600060
# Count: 1106 	x = 601156
# Count: 1107 	x = 602253
# Count: 1108 	x = 603351
# Count: 1109 	x = 604450
# Count: 1110 	x = 605550
# Count: 1111 	x = 606651
# Count: 1112 	x = 607753
# Count: 1113 	x = 608856
# Count: 1114 	x = 609960
# Count: 1115 	x = 611065
# Count: 1116 	x = 612171
# Count: 1117 	x = 613278
# Count: 1118 	x = 614386
# Count: 1119 	x = 615495
# Count: 1120 	x = 616605
# Count: 1121 	x = 617716
# Count: 1122 	x = 618828
# Count: 1123 	x = 619941
# Count: 1124 	x = 621055
# Count: 1125 	x = 622170
# Count: 1126 	x = 623286
# Count: 1127 	x = 624403
# Count: 1128 	x = 625521
# Count: 1129 	x = 626640
# Count: 1130 	x = 627760
# Count: 1131 	x = 628881
# Count: 1132 	x = 630003
# Count: 1133 	x = 631126
# Count: 1134 	x = 632250
# Count: 1135 	x = 633375
# Count: 1136 	x = 634501
# Count: 1137 	x = 635628
# Count: 1138 	x = 636756
# Count: 1139 	x = 637885
# Count: 1140 	x = 639015
# Count: 1141 	x = 640146
# Count: 1142 	x = 641278
# Count: 1143 	x = 642411
# Count: 1144 	x = 643545
# Count: 1145 	x = 644680
# Count: 1146 	x = 645816
# Count: 1147 	x = 646953
# Count: 1148 	x = 648091
# Count: 1149 	x = 649230
# Count: 1150 	x = 650370
# Count: 1151 	x = 651511
# Count: 1152 	x = 652653
# Count: 1153 	x = 653796
# Count: 1154 	x = 654940
# Count: 1155 	x = 656085
# Count: 1156 	x = 657231
# Count: 1157 	x = 658378
# Count: 1158 	x = 659526
# Count: 1159 	x = 660675
# Count: 1160 	x = 661825
# Count: 1161 	x = 662976
# Count: 1162 	x = 664128
# Count: 1163 	x = 665281
# Count: 1164 	x = 666435
# Count: 1165 	x = 667590
# Count: 1166 	x = 668746
# Count: 1167 	x = 669903
# Count: 1168 	x = 671061
# Count: 1169 	x = 672220
# Count: 1170 	x = 673380
# Count: 1171 	x = 674541
# Count: 1172 	x = 675703
# Count: 1173 	x = 676866
# Count: 1174 	x = 678030
# Count: 1175 	x = 679195
# Count: 1176 	x = 680361
# Count: 1177 	x = 681528
# Count: 1178 	x = 682696
# Count: 1179 	x = 683865
# Count: 1180 	x = 685035
# Count: 1181 	x = 686206
# Count: 1182 	x = 687378
# Count: 1183 	x = 688551
# Count: 1184 	x = 689725
# Count: 1185 	x = 690900
# Count: 1186 	x = 692076
# Count: 1187 	x = 693253
# Count: 1188 	x = 694431
# Count: 1189 	x = 695610
# Count: 1190 	x = 696790
# Count: 1191 	x = 697971
# Count: 1192 	x = 699153
# Count: 1193 	x = 700336
# Count: 1194 	x = 701520
# Count: 1195 	x = 702705
# Count: 1196 	x = 703891
# Count: 1197 	x = 705078
# Count: 1198 	x = 706266
# Count: 1199 	x = 707455
# Count: 1200 	x = 708645
# Count: 1201 	x = 709836
# Count: 1202 	x = 711028
# Count: 1203 	x = 712221
# Count: 1204 	x = 713415
# Count: 1205 	x = 714610
# Count: 1206 	x = 715806
# Count: 1207 	x = 717003
# Count: 1208 	x = 718201
# Count: 1209 	x = 719400
# Count: 1210 	x = 720600
# Count: 1211 	x = 721801
# Count: 1212 	x = 723003
# Count: 1213 	x = 724206
# Count: 1214 	x = 725410
# Count: 1215 	x = 726615
# Count: 1216 	x = 727821
# Count: 1217 	x = 729028
# Count: 1218 	x = 730236
# Count: 1219 	x = 731445
# Count: 1220 	x = 732655
# Count: 1221 	x = 733866
# Count: 1222 	x = 735078
# Count: 1223 	x = 736291
# Count: 1224 	x = 737505
# Count: 1225 	x = 738720
# Count: 1226 	x = 739936
# Count: 1227 	x = 741153
# Count: 1228 	x = 742371
# Count: 1229 	x = 743590
# Count: 1230 	x = 744810
# Count: 1231 	x = 746031
# Count: 1232 	x = 747253
# Count: 1233 	x = 748476
# Count: 1234 	x = 749700
# Count: 1235 	x = 750925
# Count: 1236 	x = 752151
# Count: 1237 	x = 753378
# Count: 1238 	x = 754606
# Count: 1239 	x = 755835
# Count: 1240 	x = 757065
# Count: 1241 	x = 758296
# Count: 1242 	x = 759528
# Count: 1243 	x = 760761
# Count: 1244 	x = 761995
# Count: 1245 	x = 763230
# Count: 1246 	x = 764466
# Count: 1247 	x = 765703
# Count: 1248 	x = 766941
# Count: 1249 	x = 768180
# Count: 1250 	x = 769420
# Count: 1251 	x = 770661
# Count: 1252 	x = 771903
# Count: 1253 	x = 773146
# Count: 1254 	x = 774390
# Count: 1255 	x = 775635
# Count: 1256 	x = 776881
# Count: 1257 	x = 778128
# Count: 1258 	x = 779376
# Count: 1259 	x = 780625
# Count: 1260 	x = 781875
# Count: 1261 	x = 783126
# Count: 1262 	x = 784378
# Count: 1263 	x = 785631
# Count: 1264 	x = 786885
# Count: 1265 	x = 788140
# Count: 1266 	x = 789396
# Count: 1267 	x = 790653
# Count: 1268 	x = 791911
# Count: 1269 	x = 793170
# Count: 1270 	x = 794430
# Count: 1271 	x = 795691
# Count: 1272 	x = 796953
# Count: 1273 	x = 798216
# Count: 1274 	x = 799480
# Count: 1275 	x = 800745
# Count: 1276 	x = 802011
# Count: 1277 	x = 803278
# Count: 1278 	x = 804546
# Count: 1279 	x = 805815
# Count: 1280 	x = 807085
# Count: 1281 	x = 808356
# Count: 1282 	x = 809628
# Count: 1283 	x = 810901
# Count: 1284 	x = 812175
# Count: 1285 	x = 813450
# Count: 1286 	x = 814726
# Count: 1287 	x = 816003
# Count: 1288 	x = 817281
# Count: 1289 	x = 818560
# Count: 1290 	x = 819840
# Count: 1291 	x = 821121
# Count: 1292 	x = 822403
# Count: 1293 	x = 823686
# Count: 1294 	x = 824970
# Count: 1295 	x = 826255
# Count: 1296 	x = 827541
# Count: 1297 	x = 828828
# Count: 1298 	x = 830116
# Count: 1299 	x = 831405
# Count: 1300 	x = 832695
# Count: 1301 	x = 833986
# Count: 1302 	x = 835278
# Count: 1303 	x = 836571
# Count: 1304 	x = 837865
# Count: 1305 	x = 839160
# Count: 1306 	x = 840456
# Count: 1307 	x = 841753
# Count: 1308 	x = 843051
# Count: 1309 	x = 844350
# Count: 1310 	x = 845650
# Count: 1311 	x = 846951
# Count: 1312 	x = 848253
# Count: 1313 	x = 849556
# Count: 1314 	x = 850860
# Count: 1315 	x = 852165
# Count: 1316 	x = 853471
# Count: 1317 	x = 854778
# Count: 1318 	x = 856086
# Count: 1319 	x = 857395
# Count: 1320 	x = 858705
# Count: 1321 	x = 860016
# Count: 1322 	x = 861328
# Count: 1323 	x = 862641
# Count: 1324 	x = 863955
# Count: 1325 	x = 865270
# Count: 1326 	x = 866586
# Count: 1327 	x = 867903
# Count: 1328 	x = 869221
# Count: 1329 	x = 870540
# Count: 1330 	x = 871860
# Count: 1331 	x = 873181
# Count: 1332 	x = 874503
# Count: 1333 	x = 875826
# Count: 1334 	x = 877150
# Count: 1335 	x = 878475
# Count: 1336 	x = 879801
# Count: 1337 	x = 881128
# Count: 1338 	x = 882456
# Count: 1339 	x = 883785
# Count: 1340 	x = 885115
# Count: 1341 	x = 886446
# Count: 1342 	x = 887778
# Count: 1343 	x = 889111
# Count: 1344 	x = 890445
# Count: 1345 	x = 891780
# Count: 1346 	x = 893116
# Count: 1347 	x = 894453
# Count: 1348 	x = 895791
# Count: 1349 	x = 897130
# Count: 1350 	x = 898470
# Count: 1351 	x = 899811
# Count: 1352 	x = 901153
# Count: 1353 	x = 902496
# Count: 1354 	x = 903840
# Count: 1355 	x = 905185
# Count: 1356 	x = 906531
# Count: 1357 	x = 907878
# Count: 1358 	x = 909226
# Count: 1359 	x = 910575
# Count: 1360 	x = 911925
# Count: 1361 	x = 913276
# Count: 1362 	x = 914628
# Count: 1363 	x = 915981
# Count: 1364 	x = 917335
# Count: 1365 	x = 918690
# Count: 1366 	x = 920046
# Count: 1367 	x = 921403
# Count: 1368 	x = 922761
# Count: 1369 	x = 924120
# Count: 1370 	x = 925480
# Count: 1371 	x = 926841
# Count: 1372 	x = 928203
# Count: 1373 	x = 929566
# Count: 1374 	x = 930930
# Count: 1375 	x = 932295
# Count: 1376 	x = 933661
# Count: 1377 	x = 935028
# Count: 1378 	x = 936396
# Count: 1379 	x = 937765
# Count: 1380 	x = 939135
# Count: 1381 	x = 940506
# Count: 1382 	x = 941878
# Count: 1383 	x = 943251
# Count: 1384 	x = 944625
# Count: 1385 	x = 946000
# Count: 1386 	x = 947376
# Count: 1387 	x = 948753
# Count: 1388 	x = 950131
# Count: 1389 	x = 951510
# Count: 1390 	x = 952890
# Count: 1391 	x = 954271
# Count: 1392 	x = 955653
# Count: 1393 	x = 957036
# Count: 1394 	x = 958420
# Count: 1395 	x = 959805
# Count: 1396 	x = 961191
# Count: 1397 	x = 962578
# Count: 1398 	x = 963966
# Count: 1399 	x = 965355
# Count: 1400 	x = 966745
# Count: 1401 	x = 968136
# Count: 1402 	x = 969528
# Count: 1403 	x = 970921
# Count: 1404 	x = 972315
# Count: 1405 	x = 973710
# Count: 1406 	x = 975106
# Count: 1407 	x = 976503
# Count: 1408 	x = 977901
# Count: 1409 	x = 979300
# Count: 1410 	x = 980700
# Count: 1411 	x = 982101
# Count: 1412 	x = 983503
# Count: 1413 	x = 984906
# Count: 1414 	x = 986310
# Count: 1415 	x = 987715
# Count: 1416 	x = 989121
# Count: 1417 	x = 990528
# Count: 1418 	x = 991936
# Count: 1419 	x = 993345
# Count: 1420 	x = 994755
# Count: 1421 	x = 996166
# Count: 1422 	x = 997578
# Count: 1423 	x = 998991
# Count: 1424 	x = 1000405
# Count: 1425 	x = 1001820
# Count: 1426 	x = 1003236
# Count: 1427 	x = 1004653
# Count: 1428 	x = 1006071
# Count: 1429 	x = 1007490
# Count: 1430 	x = 1008910
# Count: 1431 	x = 1010331
# Count: 1432 	x = 1011753
# Count: 1433 	x = 1013176
# Count: 1434 	x = 1014600
# Count: 1435 	x = 1016025
# Count: 1436 	x = 1017451
# Count: 1437 	x = 1018878
# Count: 1438 	x = 1020306
# Count: 1439 	x = 1021735
# Count: 1440 	x = 1023165
# Count: 1441 	x = 1024596
# Count: 1442 	x = 1026028
# Count: 1443 	x = 1027461
# Count: 1444 	x = 1028895
# Count: 1445 	x = 1030330
# Count: 1446 	x = 1031766
# Count: 1447 	x = 1033203
# Count: 1448 	x = 1034641
# Count: 1449 	x = 1036080
# Count: 1450 	x = 1037520
# Count: 1451 	x = 1038961
# Count: 1452 	x = 1040403
# Count: 1453 	x = 1041846
# Count: 1454 	x = 1043290
# Count: 1455 	x = 1044735
# Count: 1456 	x = 1046181
# Count: 1457 	x = 1047628
# Count: 1458 	x = 1049076
# Count: 1459 	x = 1050525
# Count: 1460 	x = 1051975
# Count: 1461 	x = 1053426
# Count: 1462 	x = 1054878
# Count: 1463 	x = 1056331
# Count: 1464 	x = 1057785
# Count: 1465 	x = 1059240
# Count: 1466 	x = 1060696
# Count: 1467 	x = 1062153
# Count: 1468 	x = 1063611
# Count: 1469 	x = 1065070
# Count: 1470 	x = 1066530
# Count: 1471 	x = 1067991
# Count: 1472 	x = 1069453
# Count: 1473 	x = 1070916
# Count: 1474 	x = 1072380
# Count: 1475 	x = 1073845
# Count: 1476 	x = 1075311
# Count: 1477 	x = 1076778
# Count: 1478 	x = 1078246
# Count: 1479 	x = 1079715
# Count: 1480 	x = 1081185
# Count: 1481 	x = 1082656
# Count: 1482 	x = 1084128
# Count: 1483 	x = 1085601
# Count: 1484 	x = 1087075
# Count: 1485 	x = 1088550
# Count: 1486 	x = 1090026
# Count: 1487 	x = 1091503
# Count: 1488 	x = 1092981
# Count: 1489 	x = 1094460
# Count: 1490 	x = 1095940
# Count: 1491 	x = 1097421
# Count: 1492 	x = 1098903
# Count: 1493 	x = 1100386
# Count: 1494 	x = 1101870
# Count: 1495 	x = 1103355
# Count: 1496 	x = 1104841
# Count: 1497 	x = 1106328
# Count: 1498 	x = 1107816
# Count: 1499 	x = 1109305
# Count: 1500 	x = 1110795
# Count: 1501 	x = 1112286
# Count: 1502 	x = 1113778
# Count: 1503 	x = 1115271
# Count: 1504 	x = 1116765
# Count: 1505 	x = 1118260
# Count: 1506 	x = 1119756
# Count: 1507 	x = 1121253
# Count: 1508 	x = 1122751
# Count: 1509 	x = 1124250
# Count: 1510 	x = 1125750
# Count: 1511 	x = 1127251
# Count: 1512 	x = 1128753
# Count: 1513 	x = 1130256
# Count: 1514 	x = 1131760
# Count: 1515 	x = 1133265
# Count: 1516 	x = 1134771
# Count: 1517 	x = 1136278
# Count: 1518 	x = 1137786
# Count: 1519 	x = 1139295
# Count: 1520 	x = 1140805
# Count: 1521 	x = 1142316
# Count: 1522 	x = 1143828
# Count: 1523 	x = 1145341
# Count: 1524 	x = 1146855
# Count: 1525 	x = 1148370
# Count: 1526 	x = 1149886
# Count: 1527 	x = 1151403
# Count: 1528 	x = 1152921
# Count: 1529 	x = 1154440
# Count: 1530 	x = 1155960
# Count: 1531 	x = 1157481
# Count: 1532 	x = 1159003
# Count: 1533 	x = 1160526
# Count: 1534 	x = 1162050
# Count: 1535 	x = 1163575
# Count: 1536 	x = 1165101
# Count: 1537 	x = 1166628
# Count: 1538 	x = 1168156
# Count: 1539 	x = 1169685
# Count: 1540 	x = 1171215
# Count: 1541 	x = 1172746
# Count: 1542 	x = 1174278
# Count: 1543 	x = 1175811
# Count: 1544 	x = 1177345
# Count: 1545 	x = 1178880
# Count: 1546 	x = 1180416
# Count: 1547 	x = 1181953
# Count: 1548 	x = 1183491
# Count: 1549 	x = 1185030
# Count: 1550 	x = 1186570
# Count: 1551 	x = 1188111
# Count: 1552 	x = 1189653
# Count: 1553 	x = 1191196
# Count: 1554 	x = 1192740
# Count: 1555 	x = 1194285
# Count: 1556 	x = 1195831
# Count: 1557 	x = 1197378
# Count: 1558 	x = 1198926
# Count: 1559 	x = 1200475
# Count: 1560 	x = 1202025
# Count: 1561 	x = 1203576
# Count: 1562 	x = 1205128
# Count: 1563 	x = 1206681
# Count: 1564 	x = 1208235
# Count: 1565 	x = 1209790
# Count: 1566 	x = 1211346
# Count: 1567 	x = 1212903
# Count: 1568 	x = 1214461
# Count: 1569 	x = 1216020
# Count: 1570 	x = 1217580
# Count: 1571 	x = 1219141
# Count: 1572 	x = 1220703
# Count: 1573 	x = 1222266
# Count: 1574 	x = 1223830
# Count: 1575 	x = 1225395
# Count: 1576 	x = 1226961
# Count: 1577 	x = 1228528
# Count: 1578 	x = 1230096
# Count: 1579 	x = 1231665
# Count: 1580 	x = 1233235
# Count: 1581 	x = 1234806
# Count: 1582 	x = 1236378
# Count: 1583 	x = 1237951
# Count: 1584 	x = 1239525
# Count: 1585 	x = 1241100
# Count: 1586 	x = 1242676
# Count: 1587 	x = 1244253
# Count: 1588 	x = 1245831
# Count: 1589 	x = 1247410
# Count: 1590 	x = 1248990
# Count: 1591 	x = 1250571
# Count: 1592 	x = 1252153
# Count: 1593 	x = 1253736
# Count: 1594 	x = 1255320
# Count: 1595 	x = 1256905
# Count: 1596 	x = 1258491
# Count: 1597 	x = 1260078
# Count: 1598 	x = 1261666
# Count: 1599 	x = 1263255
# Count: 1600 	x = 1264845
# Count: 1601 	x = 1266436
# Count: 1602 	x = 1268028
# Count: 1603 	x = 1269621
# Count: 1604 	x = 1271215
# Count: 1605 	x = 1272810
# Count: 1606 	x = 1274406
# Count: 1607 	x = 1276003
# Count: 1608 	x = 1277601
# Count: 1609 	x = 1279200
# Count: 1610 	x = 1280800
# Count: 1611 	x = 1282401
# Count: 1612 	x = 1284003
# Count: 1613 	x = 1285606
# Count: 1614 	x = 1287210
# Count: 1615 	x = 1288815
# Count: 1616 	x = 1290421
# Count: 1617 	x = 1292028
# Count: 1618 	x = 1293636
# Count: 1619 	x = 1295245
# Count: 1620 	x = 1296855
# Count: 1621 	x = 1298466
# Count: 1622 	x = 1300078
# Count: 1623 	x = 1301691
# Count: 1624 	x = 1303305
# Count: 1625 	x = 1304920
# Count: 1626 	x = 1306536
# Count: 1627 	x = 1308153
# Count: 1628 	x = 1309771
# Count: 1629 	x = 1311390
# Count: 1630 	x = 1313010
# Count: 1631 	x = 1314631
# Count: 1632 	x = 1316253
# Count: 1633 	x = 1317876
# Count: 1634 	x = 1319500
# Count: 1635 	x = 1321125
# Count: 1636 	x = 1322751
# Count: 1637 	x = 1324378
# Count: 1638 	x = 1326006
# Count: 1639 	x = 1327635
# Count: 1640 	x = 1329265
# Count: 1641 	x = 1330896
# Count: 1642 	x = 1332528
# Count: 1643 	x = 1334161
# Count: 1644 	x = 1335795
# Count: 1645 	x = 1337430
# Count: 1646 	x = 1339066
# Count: 1647 	x = 1340703
# Count: 1648 	x = 1342341
# Count: 1649 	x = 1343980
# Count: 1650 	x = 1345620
# Count: 1651 	x = 1347261
# Count: 1652 	x = 1348903
# Count: 1653 	x = 1350546
# Count: 1654 	x = 1352190
# Count: 1655 	x = 1353835
# Count: 1656 	x = 1355481
# Count: 1657 	x = 1357128
# Count: 1658 	x = 1358776
# Count: 1659 	x = 1360425
# Count: 1660 	x = 1362075
# Count: 1661 	x = 1363726
# Count: 1662 	x = 1365378
# Count: 1663 	x = 1367031
# Count: 1664 	x = 1368685
# Count: 1665 	x = 1370340
# Count: 1666 	x = 1371996
# Count: 1667 	x = 1373653
# Count: 1668 	x = 1375311
# Count: 1669 	x = 1376970
# Count: 1670 	x = 1378630
# Count: 1671 	x = 1380291
# Count: 1672 	x = 1381953
# Count: 1673 	x = 1383616
# Count: 1674 	x = 1385280
# Count: 1675 	x = 1386945
# Count: 1676 	x = 1388611
# Count: 1677 	x = 1390278
# Count: 1678 	x = 1391946
# Count: 1679 	x = 1393615
# Count: 1680 	x = 1395285
# Count: 1681 	x = 1396956
# Count: 1682 	x = 1398628
# Count: 1683 	x = 1400301
# Count: 1684 	x = 1401975
# Count: 1685 	x = 1403650
# Count: 1686 	x = 1405326
# Count: 1687 	x = 1407003
# Count: 1688 	x = 1408681
# Count: 1689 	x = 1410360
# Count: 1690 	x = 1412040
# Count: 1691 	x = 1413721
# Count: 1692 	x = 1415403
# Count: 1693 	x = 1417086
# Count: 1694 	x = 1418770
# Count: 1695 	x = 1420455
# Count: 1696 	x = 1422141
# Count: 1697 	x = 1423828
# Count: 1698 	x = 1425516
# Count: 1699 	x = 1427205
# Count: 1700 	x = 1428895
# Count: 1701 	x = 1430586
# Count: 1702 	x = 1432278
# Count: 1703 	x = 1433971
# Count: 1704 	x = 1435665
# Count: 1705 	x = 1437360
# Count: 1706 	x = 1439056
# Count: 1707 	x = 1440753
# Count: 1708 	x = 1442451
# Count: 1709 	x = 1444150
# Count: 1710 	x = 1445850
# Count: 1711 	x = 1447551
# Count: 1712 	x = 1449253
# Count: 1713 	x = 1450956
# Count: 1714 	x = 1452660
# Count: 1715 	x = 1454365
# Count: 1716 	x = 1456071
# Count: 1717 	x = 1457778
# Count: 1718 	x = 1459486
# Count: 1719 	x = 1461195
# Count: 1720 	x = 1462905
# Count: 1721 	x = 1464616
# Count: 1722 	x = 1466328
# Count: 1723 	x = 1468041
# Count: 1724 	x = 1469755
# Count: 1725 	x = 1471470
# Count: 1726 	x = 1473186
# Count: 1727 	x = 1474903
# Count: 1728 	x = 1476621
# Count: 1729 	x = 1478340
# Count: 1730 	x = 1480060
# Count: 1731 	x = 1481781
# Count: 1732 	x = 1483503
# Count: 1733 	x = 1485226
# Count: 1734 	x = 1486950
# Count: 1735 	x = 1488675
# Count: 1736 	x = 1490401
# Count: 1737 	x = 1492128
# Count: 1738 	x = 1493856
# Count: 1739 	x = 1495585
# Count: 1740 	x = 1497315
# Count: 1741 	x = 1499046
# Count: 1742 	x = 1500778
# Count: 1743 	x = 1502511
# Count: 1744 	x = 1504245
# Count: 1745 	x = 1505980
# Count: 1746 	x = 1507716
# Count: 1747 	x = 1509453
# Count: 1748 	x = 1511191
# Count: 1749 	x = 1512930
# Count: 1750 	x = 1514670
# Count: 1751 	x = 1516411
# Count: 1752 	x = 1518153
# Count: 1753 	x = 1519896
# Count: 1754 	x = 1521640
# Count: 1755 	x = 1523385
# Count: 1756 	x = 1525131
# Count: 1757 	x = 1526878
# Count: 1758 	x = 1528626
# Count: 1759 	x = 1530375
# Count: 1760 	x = 1532125
# Count: 1761 	x = 1533876
# Count: 1762 	x = 1535628
# Count: 1763 	x = 1537381
# Count: 1764 	x = 1539135
# Count: 1765 	x = 1540890
# Count: 1766 	x = 1542646
# Count: 1767 	x = 1544403
# Count: 1768 	x = 1546161
# Count: 1769 	x = 1547920
# Count: 1770 	x = 1549680
# Count: 1771 	x = 1551441
# Count: 1772 	x = 1553203
# Count: 1773 	x = 1554966
# Count: 1774 	x = 1556730
# Count: 1775 	x = 1558495
# Count: 1776 	x = 1560261
# Count: 1777 	x = 1562028
# Count: 1778 	x = 1563796
# Count: 1779 	x = 1565565
# Count: 1780 	x = 1567335
# Count: 1781 	x = 1569106
# Count: 1782 	x = 1570878
# Count: 1783 	x = 1572651
# Count: 1784 	x = 1574425
# Count: 1785 	x = 1576200
# Count: 1786 	x = 1577976
# Count: 1787 	x = 1579753
# Count: 1788 	x = 1581531
# Count: 1789 	x = 1583310
# Count: 1790 	x = 1585090
# Count: 1791 	x = 1586871
# Count: 1792 	x = 1588653
# Count: 1793 	x = 1590436
# Count: 1794 	x = 1592220
# Count: 1795 	x = 1594005
# Count: 1796 	x = 1595791
# Count: 1797 	x = 1597578
# Count: 1798 	x = 1599366
# Count: 1799 	x = 1601155
# Count: 1800 	x = 1602945
# Count: 1801 	x = 1604736
# Count: 1802 	x = 1606528
# Count: 1803 	x = 1608321
# Count: 1804 	x = 1610115
# Count: 1805 	x = 1611910
# Count: 1806 	x = 1613706
# Count: 1807 	x = 1615503
# Count: 1808 	x = 1617301
# Count: 1809 	x = 1619100
# Count: 1810 	x = 1620900
# Count: 1811 	x = 1622701
# Count: 1812 	x = 1624503
# Count: 1813 	x = 1626306
# Count: 1814 	x = 1628110
# Count: 1815 	x = 1629915
# Count: 1816 	x = 1631721
# Count: 1817 	x = 1633528
# Count: 1818 	x = 1635336
# Count: 1819 	x = 1637145
# Count: 1820 	x = 1638955
# Count: 1821 	x = 1640766
# Count: 1822 	x = 1642578
# Count: 1823 	x = 1644391
# Count: 1824 	x = 1646205
# Count: 1825 	x = 1648020
# Count: 1826 	x = 1649836
# Count: 1827 	x = 1651653
# Count: 1828 	x = 1653471
# Count: 1829 	x = 1655290
# Count: 1830 	x = 1657110
# Count: 1831 	x = 1658931
# Count: 1832 	x = 1660753
# Count: 1833 	x = 1662576
# Count: 1834 	x = 1664400
# Count: 1835 	x = 1666225
# Count: 1836 	x = 1668051
# Count: 1837 	x = 1669878
# Count: 1838 	x = 1671706
# Count: 1839 	x = 1673535
# Count: 1840 	x = 1675365
# Count: 1841 	x = 1677196
# Count: 1842 	x = 1679028
# Count: 1843 	x = 1680861
# Count: 1844 	x = 1682695
# Count: 1845 	x = 1684530
# Count: 1846 	x = 1686366
# Count: 1847 	x = 1688203
# Count: 1848 	x = 1690041
# Count: 1849 	x = 1691880
# Count: 1850 	x = 1693720
# Count: 1851 	x = 1695561
# Count: 1852 	x = 1697403
# Count: 1853 	x = 1699246
# Count: 1854 	x = 1701090
# Count: 1855 	x = 1702935
# Count: 1856 	x = 1704781
# Count: 1857 	x = 1706628
# Count: 1858 	x = 1708476
# Count: 1859 	x = 1710325
# Count: 1860 	x = 1712175
# Count: 1861 	x = 1714026
# Count: 1862 	x = 1715878
# Count: 1863 	x = 1717731
# Count: 1864 	x = 1719585
# Count: 1865 	x = 1721440
# Count: 1866 	x = 1723296
# Count: 1867 	x = 1725153
# Count: 1868 	x = 1727011
# Count: 1869 	x = 1728870
# Count: 1870 	x = 1730730
# Count: 1871 	x = 1732591
# Count: 1872 	x = 1734453
# Count: 1873 	x = 1736316
# Count: 1874 	x = 1738180
# Count: 1875 	x = 1740045
# Count: 1876 	x = 1741911
# Count: 1877 	x = 1743778
# Count: 1878 	x = 1745646
# Count: 1879 	x = 1747515
# Count: 1880 	x = 1749385
# Count: 1881 	x = 1751256
# Count: 1882 	x = 1753128
# Count: 1883 	x = 1755001
# Count: 1884 	x = 1756875
# Count: 1885 	x = 1758750
# Count: 1886 	x = 1760626
# Count: 1887 	x = 1762503
# Count: 1888 	x = 1764381
# Count: 1889 	x = 1766260
# Count: 1890 	x = 1768140
# Count: 1891 	x = 1770021
# Count: 1892 	x = 1771903
# Count: 1893 	x = 1773786
# Count: 1894 	x = 1775670
# Count: 1895 	x = 1777555
# Count: 1896 	x = 1779441
# Count: 1897 	x = 1781328
# Count: 1898 	x = 1783216
# Count: 1899 	x = 1785105
# Count: 1900 	x = 1786995
# Count: 1901 	x = 1788886
# Count: 1902 	x = 1790778
# Count: 1903 	x = 1792671
# Count: 1904 	x = 1794565
# Count: 1905 	x = 1796460
# Count: 1906 	x = 1798356
# Count: 1907 	x = 1800253
# Count: 1908 	x = 1802151
# Count: 1909 	x = 1804050
# Count: 1910 	x = 1805950
# Count: 1911 	x = 1807851
# Count: 1912 	x = 1809753
# Count: 1913 	x = 1811656
# Count: 1914 	x = 1813560
# Count: 1915 	x = 1815465
# Count: 1916 	x = 1817371
# Count: 1917 	x = 1819278
# Count: 1918 	x = 1821186
# Count: 1919 	x = 1823095
# Count: 1920 	x = 1825005
# Count: 1921 	x = 1826916
# Count: 1922 	x = 1828828
# Count: 1923 	x = 1830741
# Count: 1924 	x = 1832655
# Count: 1925 	x = 1834570
# Count: 1926 	x = 1836486
# Count: 1927 	x = 1838403
# Count: 1928 	x = 1840321
# Count: 1929 	x = 1842240
# Count: 1930 	x = 1844160
# Count: 1931 	x = 1846081
# Count: 1932 	x = 1848003
# Count: 1933 	x = 1849926
# Count: 1934 	x = 1851850
# Count: 1935 	x = 1853775
# Count: 1936 	x = 1855701
# Count: 1937 	x = 1857628
# Count: 1938 	x = 1859556
# Count: 1939 	x = 1861485
# Count: 1940 	x = 1863415
# Count: 1941 	x = 1865346
# Count: 1942 	x = 1867278
# Count: 1943 	x = 1869211
# Count: 1944 	x = 1871145
# Count: 1945 	x = 1873080
# Count: 1946 	x = 1875016
# Count: 1947 	x = 1876953
# Count: 1948 	x = 1878891
# Count: 1949 	x = 1880830
# Count: 1950 	x = 1882770
# Count: 1951 	x = 1884711
# Count: 1952 	x = 1886653
# Count: 1953 	x = 1888596
# Count: 1954 	x = 1890540
# Count: 1955 	x = 1892485
# Count: 1956 	x = 1894431
# Count: 1957 	x = 1896378
# Count: 1958 	x = 1898326
# Count: 1959 	x = 1900275
# Count: 1960 	x = 1902225
# Count: 1961 	x = 1904176
# Count: 1962 	x = 1906128
# Count: 1963 	x = 1908081
# Count: 1964 	x = 1910035
# Count: 1965 	x = 1911990
# Count: 1966 	x = 1913946
# Count: 1967 	x = 1915903
# Count: 1968 	x = 1917861
# Count: 1969 	x = 1919820
# Count: 1970 	x = 1921780
# Count: 1971 	x = 1923741
# Count: 1972 	x = 1925703
# Count: 1973 	x = 1927666
# Count: 1974 	x = 1929630
# Count: 1975 	x = 1931595
# Count: 1976 	x = 1933561
# Count: 1977 	x = 1935528
# Count: 1978 	x = 1937496
# Count: 1979 	x = 1939465
# Count: 1980 	x = 1941435
# Count: 1981 	x = 1943406
# Count: 1982 	x = 1945378
# Count: 1983 	x = 1947351
# Count: 1984 	x = 1949325
# Count: 1985 	x = 1951300
# Count: 1986 	x = 1953276
# Count: 1987 	x = 1955253
# Count: 1988 	x = 1957231
# Count: 1989 	x = 1959210
# Count: 1990 	x = 1961190
# Count: 1991 	x = 1963171
# Count: 1992 	x = 1965153
# Count: 1993 	x = 1967136
# Count: 1994 	x = 1969120
# Count: 1995 	x = 1971105
# Count: 1996 	x = 1973091
# Count: 1997 	x = 1975078
# Count: 1998 	x = 1977066
# Count: 1999 	x = 1979055
# Count: 2000 	x = 1981045
# Count: 2001 	x = 1983036
# Count: 2002 	x = 1985028
# Count: 2003 	x = 1987021
# Count: 2004 	x = 1989015
# Count: 2005 	x = 1991010
# Count: 2006 	x = 1993006
# Count: 2007 	x = 1995003
# Count: 2008 	x = 1997001
# Count: 2009 	x = 1999000
# Count: 2010 	x = 2001000
# 0.010811090469360352

# %%
import time

start = time.time()

demo_0(1000)

print(time.time() - start)
# Out:
# 1 	 3
# 2 	 5
# 3 	 7
# 4 	 9
# 5 	 11
# 6 	 13
# 7 	 15
# 8 	 17
# 9 	 19
# 10 	 21
# 11 	 23
# 12 	 25
# 13 	 27
# 14 	 29
# 15 	 31
# 16 	 33
# 17 	 35
# 18 	 37
# 19 	 39
# 20 	 41
# 21 	 43
# 22 	 45
# 23 	 47
# 24 	 49
# 25 	 51
# 26 	 53
# 27 	 55
# 28 	 57
# 29 	 59
# 30 	 61
# 31 	 63
# 32 	 65
# 33 	 67
# 34 	 69
# 35 	 71
# 36 	 73
# 37 	 75
# 38 	 77
# 39 	 79
# 40 	 81
# 41 	 83
# 42 	 85
# 43 	 87
# 44 	 89
# 45 	 91
# 46 	 93
# 47 	 95
# 48 	 97
# 49 	 99
# 50 	 101
# 51 	 103
# 52 	 105
# 53 	 107
# 54 	 109
# 55 	 111
# 56 	 113
# 57 	 115
# 58 	 117
# 59 	 119
# 60 	 121
# 61 	 123
# 62 	 125
# 63 	 127
# 64 	 129
# 65 	 131
# 66 	 133
# 67 	 135
# 68 	 137
# 69 	 139
# 70 	 141
# 71 	 143
# 72 	 145
# 73 	 147
# 74 	 149
# 75 	 151
# 76 	 153
# 77 	 155
# 78 	 157
# 79 	 159
# 80 	 161
# 81 	 163
# 82 	 165
# 83 	 167
# 84 	 169
# 85 	 171
# 86 	 173
# 87 	 175
# 88 	 177
# 89 	 179
# 90 	 181
# 91 	 183
# 92 	 185
# 93 	 187
# 94 	 189
# 95 	 191
# 96 	 193
# 97 	 195
# 98 	 197
# 99 	 199
# 100 	 201
# 101 	 203
# 102 	 205
# 103 	 207
# 104 	 209
# 105 	 211
# 106 	 213
# 107 	 215
# 108 	 217
# 109 	 219
# 110 	 221
# 111 	 223
# 112 	 225
# 113 	 227
# 114 	 229
# 115 	 231
# 116 	 233
# 117 	 235
# 118 	 237
# 119 	 239
# 120 	 241
# 121 	 243
# 122 	 245
# 123 	 247
# 124 	 249
# 125 	 251
# 126 	 253
# 127 	 255
# 128 	 257
# 129 	 259
# 130 	 261
# 131 	 263
# 132 	 265
# 133 	 267
# 134 	 269
# 135 	 271
# 136 	 273
# 137 	 275
# 138 	 277
# 139 	 279
# 140 	 281
# 141 	 283
# 142 	 285
# 143 	 287
# 144 	 289
# 145 	 291
# 146 	 293
# 147 	 295
# 148 	 297
# 149 	 299
# 150 	 301
# 151 	 303
# 152 	 305
# 153 	 307
# 154 	 309
# 155 	 311
# 156 	 313
# 157 	 315
# 158 	 317
# 159 	 319
# 160 	 321
# 161 	 323
# 162 	 325
# 163 	 327
# 164 	 329
# 165 	 331
# 166 	 333
# 167 	 335
# 168 	 337
# 169 	 339
# 170 	 341
# 171 	 343
# 172 	 345
# 173 	 347
# 174 	 349
# 175 	 351
# 176 	 353
# 177 	 355
# 178 	 357
# 179 	 359
# 180 	 361
# 181 	 363
# 182 	 365
# 183 	 367
# 184 	 369
# 185 	 371
# 186 	 373
# 187 	 375
# 188 	 377
# 189 	 379
# 190 	 381
# 191 	 383
# 192 	 385
# 193 	 387
# 194 	 389
# 195 	 391
# 196 	 393
# 197 	 395
# 198 	 397
# 199 	 399
# 200 	 401
# 201 	 403
# 202 	 405
# 203 	 407
# 204 	 409
# 205 	 411
# 206 	 413
# 207 	 415
# 208 	 417
# 209 	 419
# 210 	 421
# 211 	 423
# 212 	 425
# 213 	 427
# 214 	 429
# 215 	 431
# 216 	 433
# 217 	 435
# 218 	 437
# 219 	 439
# 220 	 441
# 221 	 443
# 222 	 445
# 223 	 447
# 224 	 449
# 225 	 451
# 226 	 453
# 227 	 455
# 228 	 457
# 229 	 459
# 230 	 461
# 231 	 463
# 232 	 465
# 233 	 467
# 234 	 469
# 235 	 471
# 236 	 473
# 237 	 475
# 238 	 477
# 239 	 479
# 240 	 481
# 241 	 483
# 242 	 485
# 243 	 487
# 244 	 489
# 245 	 491
# 246 	 493
# 247 	 495
# 248 	 497
# 249 	 499
# 250 	 501
# 251 	 503
# 252 	 505
# 253 	 507
# 254 	 509
# 255 	 511
# 256 	 513
# 257 	 515
# 258 	 517
# 259 	 519
# 260 	 521
# 261 	 523
# 262 	 525
# 263 	 527
# 264 	 529
# 265 	 531
# 266 	 533
# 267 	 535
# 268 	 537
# 269 	 539
# 270 	 541
# 271 	 543
# 272 	 545
# 273 	 547
# 274 	 549
# 275 	 551
# 276 	 553
# 277 	 555
# 278 	 557
# 279 	 559
# 280 	 561
# 281 	 563
# 282 	 565
# 283 	 567
# 284 	 569
# 285 	 571
# 286 	 573
# 287 	 575
# 288 	 577
# 289 	 579
# 290 	 581
# 291 	 583
# 292 	 585
# 293 	 587
# 294 	 589
# 295 	 591
# 296 	 593
# 297 	 595
# 298 	 597
# 299 	 599
# 300 	 601
# 301 	 603
# 302 	 605
# 303 	 607
# 304 	 609
# 305 	 611
# 306 	 613
# 307 	 615
# 308 	 617
# 309 	 619
# 310 	 621
# 311 	 623
# 312 	 625
# 313 	 627
# 314 	 629
# 315 	 631
# 316 	 633
# 317 	 635
# 318 	 637
# 319 	 639
# 320 	 641
# 321 	 643
# 322 	 645
# 323 	 647
# 324 	 649
# 325 	 651
# 326 	 653
# 327 	 655
# 328 	 657
# 329 	 659
# 330 	 661
# 331 	 663
# 332 	 665
# 333 	 667
# 334 	 669
# 335 	 671
# 336 	 673
# 337 	 675
# 338 	 677
# 339 	 679
# 340 	 681
# 341 	 683
# 342 	 685
# 343 	 687
# 344 	 689
# 345 	 691
# 346 	 693
# 347 	 695
# 348 	 697
# 349 	 699
# 350 	 701
# 351 	 703
# 352 	 705
# 353 	 707
# 354 	 709
# 355 	 711
# 356 	 713
# 357 	 715
# 358 	 717
# 359 	 719
# 360 	 721
# 361 	 723
# 362 	 725
# 363 	 727
# 364 	 729
# 365 	 731
# 366 	 733
# 367 	 735
# 368 	 737
# 369 	 739
# 370 	 741
# 371 	 743
# 372 	 745
# 373 	 747
# 374 	 749
# 375 	 751
# 376 	 753
# 377 	 755
# 378 	 757
# 379 	 759
# 380 	 761
# 381 	 763
# 382 	 765
# 383 	 767
# 384 	 769
# 385 	 771
# 386 	 773
# 387 	 775
# 388 	 777
# 389 	 779
# 390 	 781
# 391 	 783
# 392 	 785
# 393 	 787
# 394 	 789
# 395 	 791
# 396 	 793
# 397 	 795
# 398 	 797
# 399 	 799
# 400 	 801
# 401 	 803
# 402 	 805
# 403 	 807
# 404 	 809
# 405 	 811
# 406 	 813
# 407 	 815
# 408 	 817
# 409 	 819
# 410 	 821
# 411 	 823
# 412 	 825
# 413 	 827
# 414 	 829
# 415 	 831
# 416 	 833
# 417 	 835
# 418 	 837
# 419 	 839
# 420 	 841
# 421 	 843
# 422 	 845
# 423 	 847
# 424 	 849
# 425 	 851
# 426 	 853
# 427 	 855
# 428 	 857
# 429 	 859
# 430 	 861
# 431 	 863
# 432 	 865
# 433 	 867
# 434 	 869
# 435 	 871
# 436 	 873
# 437 	 875
# 438 	 877
# 439 	 879
# 440 	 881
# 441 	 883
# 442 	 885
# 443 	 887
# 444 	 889
# 445 	 891
# 446 	 893
# 447 	 895
# 448 	 897
# 449 	 899
# 450 	 901
# 451 	 903
# 452 	 905
# 453 	 907
# 454 	 909
# 455 	 911
# 456 	 913
# 457 	 915
# 458 	 917
# 459 	 919
# 460 	 921
# 461 	 923
# 462 	 925
# 463 	 927
# 464 	 929
# 465 	 931
# 466 	 933
# 467 	 935
# 468 	 937
# 469 	 939
# 470 	 941
# 471 	 943
# 472 	 945
# 473 	 947
# 474 	 949
# 475 	 951
# 476 	 953
# 477 	 955
# 478 	 957
# 479 	 959
# 480 	 961
# 481 	 963
# 482 	 965
# 483 	 967
# 484 	 969
# 485 	 971
# 486 	 973
# 487 	 975
# 488 	 977
# 489 	 979
# 490 	 981
# 491 	 983
# 492 	 985
# 493 	 987
# 494 	 989
# 495 	 991
# 496 	 993
# 497 	 995
# 498 	 997
# 499 	 999
# 500 	 1001
# 501 	 1003
# 502 	 1005
# 503 	 1007
# 504 	 1009
# 505 	 1011
# 506 	 1013
# 507 	 1015
# 508 	 1017
# 509 	 1019
# 510 	 1021
# 511 	 1023
# 512 	 1025
# 513 	 1027
# 514 	 1029
# 515 	 1031
# 516 	 1033
# 517 	 1035
# 518 	 1037
# 519 	 1039
# 520 	 1041
# 521 	 1043
# 522 	 1045
# 523 	 1047
# 524 	 1049
# 525 	 1051
# 526 	 1053
# 527 	 1055
# 528 	 1057
# 529 	 1059
# 530 	 1061
# 531 	 1063
# 532 	 1065
# 533 	 1067
# 534 	 1069
# 535 	 1071
# 536 	 1073
# 537 	 1075
# 538 	 1077
# 539 	 1079
# 540 	 1081
# 541 	 1083
# 542 	 1085
# 543 	 1087
# 544 	 1089
# 545 	 1091
# 546 	 1093
# 547 	 1095
# 548 	 1097
# 549 	 1099
# 550 	 1101
# 551 	 1103
# 552 	 1105
# 553 	 1107
# 554 	 1109
# 555 	 1111
# 556 	 1113
# 557 	 1115
# 558 	 1117
# 559 	 1119
# 560 	 1121
# 561 	 1123
# 562 	 1125
# 563 	 1127
# 564 	 1129
# 565 	 1131
# 566 	 1133
# 567 	 1135
# 568 	 1137
# 569 	 1139
# 570 	 1141
# 571 	 1143
# 572 	 1145
# 573 	 1147
# 574 	 1149
# 575 	 1151
# 576 	 1153
# 577 	 1155
# 578 	 1157
# 579 	 1159
# 580 	 1161
# 581 	 1163
# 582 	 1165
# 583 	 1167
# 584 	 1169
# 585 	 1171
# 586 	 1173
# 587 	 1175
# 588 	 1177
# 589 	 1179
# 590 	 1181
# 591 	 1183
# 592 	 1185
# 593 	 1187
# 594 	 1189
# 595 	 1191
# 596 	 1193
# 597 	 1195
# 598 	 1197
# 599 	 1199
# 600 	 1201
# 601 	 1203
# 602 	 1205
# 603 	 1207
# 604 	 1209
# 605 	 1211
# 606 	 1213
# 607 	 1215
# 608 	 1217
# 609 	 1219
# 610 	 1221
# 611 	 1223
# 612 	 1225
# 613 	 1227
# 614 	 1229
# 615 	 1231
# 616 	 1233
# 617 	 1235
# 618 	 1237
# 619 	 1239
# 620 	 1241
# 621 	 1243
# 622 	 1245
# 623 	 1247
# 624 	 1249
# 625 	 1251
# 626 	 1253
# 627 	 1255
# 628 	 1257
# 629 	 1259
# 630 	 1261
# 631 	 1263
# 632 	 1265
# 633 	 1267
# 634 	 1269
# 635 	 1271
# 636 	 1273
# 637 	 1275
# 638 	 1277
# 639 	 1279
# 640 	 1281
# 641 	 1283
# 642 	 1285
# 643 	 1287
# 644 	 1289
# 645 	 1291
# 646 	 1293
# 647 	 1295
# 648 	 1297
# 649 	 1299
# 650 	 1301
# 651 	 1303
# 652 	 1305
# 653 	 1307
# 654 	 1309
# 655 	 1311
# 656 	 1313
# 657 	 1315
# 658 	 1317
# 659 	 1319
# 660 	 1321
# 661 	 1323
# 662 	 1325
# 663 	 1327
# 664 	 1329
# 665 	 1331
# 666 	 1333
# 667 	 1335
# 668 	 1337
# 669 	 1339
# 670 	 1341
# 671 	 1343
# 672 	 1345
# 673 	 1347
# 674 	 1349
# 675 	 1351
# 676 	 1353
# 677 	 1355
# 678 	 1357
# 679 	 1359
# 680 	 1361
# 681 	 1363
# 682 	 1365
# 683 	 1367
# 684 	 1369
# 685 	 1371
# 686 	 1373
# 687 	 1375
# 688 	 1377
# 689 	 1379
# 690 	 1381
# 691 	 1383
# 692 	 1385
# 693 	 1387
# 694 	 1389
# 695 	 1391
# 696 	 1393
# 697 	 1395
# 698 	 1397
# 699 	 1399
# 700 	 1401
# 701 	 1403
# 702 	 1405
# 703 	 1407
# 704 	 1409
# 705 	 1411
# 706 	 1413
# 707 	 1415
# 708 	 1417
# 709 	 1419
# 710 	 1421
# 711 	 1423
# 712 	 1425
# 713 	 1427
# 714 	 1429
# 715 	 1431
# 716 	 1433
# 717 	 1435
# 718 	 1437
# 719 	 1439
# 720 	 1441
# 721 	 1443
# 722 	 1445
# 723 	 1447
# 724 	 1449
# 725 	 1451
# 726 	 1453
# 727 	 1455
# 728 	 1457
# 729 	 1459
# 730 	 1461
# 731 	 1463
# 732 	 1465
# 733 	 1467
# 734 	 1469
# 735 	 1471
# 736 	 1473
# 737 	 1475
# 738 	 1477
# 739 	 1479
# 740 	 1481
# 741 	 1483
# 742 	 1485
# 743 	 1487
# 744 	 1489
# 745 	 1491
# 746 	 1493
# 747 	 1495
# 748 	 1497
# 749 	 1499
# 750 	 1501
# 751 	 1503
# 752 	 1505
# 753 	 1507
# 754 	 1509
# 755 	 1511
# 756 	 1513
# 757 	 1515
# 758 	 1517
# 759 	 1519
# 760 	 1521
# 761 	 1523
# 762 	 1525
# 763 	 1527
# 764 	 1529
# 765 	 1531
# 766 	 1533
# 767 	 1535
# 768 	 1537
# 769 	 1539
# 770 	 1541
# 771 	 1543
# 772 	 1545
# 773 	 1547
# 774 	 1549
# 775 	 1551
# 776 	 1553
# 777 	 1555
# 778 	 1557
# 779 	 1559
# 780 	 1561
# 781 	 1563
# 782 	 1565
# 783 	 1567
# 784 	 1569
# 785 	 1571
# 786 	 1573
# 787 	 1575
# 788 	 1577
# 789 	 1579
# 790 	 1581
# 791 	 1583
# 792 	 1585
# 793 	 1587
# 794 	 1589
# 795 	 1591
# 796 	 1593
# 797 	 1595
# 798 	 1597
# 799 	 1599
# 800 	 1601
# 801 	 1603
# 802 	 1605
# 803 	 1607
# 804 	 1609
# 805 	 1611
# 806 	 1613
# 807 	 1615
# 808 	 1617
# 809 	 1619
# 810 	 1621
# 811 	 1623
# 812 	 1625
# 813 	 1627
# 814 	 1629
# 815 	 1631
# 816 	 1633
# 817 	 1635
# 818 	 1637
# 819 	 1639
# 820 	 1641
# 821 	 1643
# 822 	 1645
# 823 	 1647
# 824 	 1649
# 825 	 1651
# 826 	 1653
# 827 	 1655
# 828 	 1657
# 829 	 1659
# 830 	 1661
# 831 	 1663
# 832 	 1665
# 833 	 1667
# 834 	 1669
# 835 	 1671
# 836 	 1673
# 837 	 1675
# 838 	 1677
# 839 	 1679
# 840 	 1681
# 841 	 1683
# 842 	 1685
# 843 	 1687
# 844 	 1689
# 845 	 1691
# 846 	 1693
# 847 	 1695
# 848 	 1697
# 849 	 1699
# 850 	 1701
# 851 	 1703
# 852 	 1705
# 853 	 1707
# 854 	 1709
# 855 	 1711
# 856 	 1713
# 857 	 1715
# 858 	 1717
# 859 	 1719
# 860 	 1721
# 861 	 1723
# 862 	 1725
# 863 	 1727
# 864 	 1729
# 865 	 1731
# 866 	 1733
# 867 	 1735
# 868 	 1737
# 869 	 1739
# 870 	 1741
# 871 	 1743
# 872 	 1745
# 873 	 1747
# 874 	 1749
# 875 	 1751
# 876 	 1753
# 877 	 1755
# 878 	 1757
# 879 	 1759
# 880 	 1761
# 881 	 1763
# 882 	 1765
# 883 	 1767
# 884 	 1769
# 885 	 1771
# 886 	 1773
# 887 	 1775
# 888 	 1777
# 889 	 1779
# 890 	 1781
# 891 	 1783
# 892 	 1785
# 893 	 1787
# 894 	 1789
# 895 	 1791
# 896 	 1793
# 897 	 1795
# 898 	 1797
# 899 	 1799
# 900 	 1801
# 901 	 1803
# 902 	 1805
# 903 	 1807
# 904 	 1809
# 905 	 1811
# 906 	 1813
# 907 	 1815
# 908 	 1817
# 909 	 1819
# 910 	 1821
# 911 	 1823
# 912 	 1825
# 913 	 1827
# 914 	 1829
# 915 	 1831
# 916 	 1833
# 917 	 1835
# 918 	 1837
# 919 	 1839
# 920 	 1841
# 921 	 1843
# 922 	 1845
# 923 	 1847
# 924 	 1849
# 925 	 1851
# 926 	 1853
# 927 	 1855
# 928 	 1857
# 929 	 1859
# 930 	 1861
# 931 	 1863
# 932 	 1865
# 933 	 1867
# 934 	 1869
# 935 	 1871
# 936 	 1873
# 937 	 1875
# 938 	 1877
# 939 	 1879
# 940 	 1881
# 941 	 1883
# 942 	 1885
# 943 	 1887
# 944 	 1889
# 945 	 1891
# 946 	 1893
# 947 	 1895
# 948 	 1897
# 949 	 1899
# 950 	 1901
# 951 	 1903
# 952 	 1905
# 953 	 1907
# 954 	 1909
# 955 	 1911
# 956 	 1913
# 957 	 1915
# 958 	 1917
# 959 	 1919
# 960 	 1921
# 961 	 1923
# 962 	 1925
# 963 	 1927
# 964 	 1929
# 965 	 1931
# 966 	 1933
# 967 	 1935
# 968 	 1937
# 969 	 1939
# 970 	 1941
# 971 	 1943
# 972 	 1945
# 973 	 1947
# 974 	 1949
# 975 	 1951
# 976 	 1953
# 977 	 1955
# 978 	 1957
# 979 	 1959
# 980 	 1961
# 981 	 1963
# 982 	 1965
# 983 	 1967
# 984 	 1969
# 985 	 1971
# 986 	 1973
# 987 	 1975
# 988 	 1977
# 989 	 1979
# 990 	 1981
# 991 	 1983
# 992 	 1985
# 993 	 1987
# 994 	 1989
# 995 	 1991
# 996 	 1993
# 997 	 1995
# 998 	 1997
# 999 	 1999
# 1000 	 2001
# 0.0059356689453125

# %% [markdown]
# <p>Fibonacci sequence</p>
# <a href="fibonacci_2.py" target="new">Fibonacci Sequence</a> and see the notes about this and
# <a href="FibonacciAndBigO.pdf">pdf about Big O</a>.</p>

# %% [markdown]
# <hr />
# <h2 style="background-color: #003262; color:white; border-radius: 4px; padding: 8px;">
# Exceptions
# </h2>

# %% [markdown]
# <h2>Try ... except block</h2>
# <p>Using the above error as a bridge, how to deal with errors before the fact?
#     <b>NB</b>: use the try...except block anytime
# <ol>
#     <li>file read/write</li>
#     <li>sql connections and read/write</li>
#     <li>any really critical data for your script</li>
#     <li>any time you want to check a variable</li>
# </ol>
# <hr />
# <blockquote>Note that it&rsquo;s important to trap and record errors.  During development we might use the <code>assert</code> command in python code.  Equally, we could use a constant lik
# </blockquote>
# <p>There are <b>built-in exceptions</b> and we can <b>define our own</b>.</p>
# <h2 style="color: #3B7EA1;">Examples</h2>
# <ul>
#     <li>File Read: 4 versions</li>
#     <li>Built-in Exceptions</li>
#     <li>Defining your own</li>
# </ul>

# %% [markdown]
# <p>
#     <img style="float:left; width: 50px; padding-right:10px;" src="images/DiscussIcon.png">
# What kinds of errors can you anticipate?  How would you handle errors - save them to a log for analysis? Send an error message to the end-user?  What about missing data or data out of range?  Or ... </p>
# <p>Here is a sequence of building up errors and try-except syntax.</p>

# %%
import os
print(os.path.abspath("testofile.txt"))
# Out:
# /Users/gb/Documents/UCB-DataSci/Fa23/wk5/testofile.txt

# %%
# 1: a generic Exception
try:
    file = open('testofile.txt')
    print('File exists')
except Exception:
    print('File does not exist')
# Out:
# File exists

# %%
# 2: a specific built-in exception FileNotFound
try:
    file = open('testofile.txt')
    print('File exists')
except FileNotFoundError as e:
    print('File does not exist:', e)
except Exception as e:
    print('An error occurred:', e)
# Out:
# File exists

# %%
# 3: Built-in and Generic Exception
# notice the odd application of "else"
try:
    file = open('testofile2.txt')
    print('File exists')
except FileNotFoundError as e:
    print('File does not exist:', e)
except Exception as e:
    print('An error occurred:', e)
else:
    print(file.read())
    file.close()
# Out:
# File exists
# Η αγάπη για τα χρήματα είναι η ρίζα κάθε κακού.

# %% [markdown]
# <blockquote>
# <pre style="color:maroon;">
# try:
#        # Some Code....
# except:
#        # optional block
#        # Handling of exception (if required)
# else:
#        # execute if no exception
# finally:
#       # Some code .....(always executed)</pre><blockquote>

# %%
def demo_divide(x, y):
    try:
        result = x // y
    except ZeroDivisionError:
        print("Yikes, Olivia!  Cannot divide by zero.")
    else:
        print(f"Yeah, Tyler! The answer is {result}.")

print(f"Demo of okay division: {demo_divide(3, 2)}")
print("-"*30)
print(f"Demo of zero division error: {demo_divide(3, 0)}")
# Out:
# Yeah, Tyler! The answer is 1.
# Demo of okay division: None
# ------------------------------
# Yikes, Olivia!  Cannot divide by zero.
# Demo of zero division error: None

# %%
# 4: as above; including the "finally"
status = ""
try:
    file = open('testofile.txt')
    print('*** [File exists.] ***\n')
    status = "Ok!"
except FileNotFoundError as e:
    print('\t[Sorry, File does not exist:', e,']')
    status = "failure"
except Exception as e:
    print(f"\t[An error occurred: {e}.]")
    status = "generic failure" # probably write to the error log
else:
    print(file.read())
    try:
        file.close()
        print(f"\n[The file has been closed.]")
    except:
        # can't close the file.
        print("\n[Sorry, can't close the file.]")
finally:
    # if sql show the status code to the end-user...
    print(f'\n[The finally area always runs. Exception or not. {status}.]')
# Out:
# *** [File exists.] ***
#
# This is testofile.txt
# 鹅、鹅、鹅    goose, goose, goose
# 曲项向天歌。  The song is singing to the sky.
# 白毛浮绿水，  White hair floats on green water,
# 红掌拨清波    Anthurium stirs clear waves
# ------------
# Morne esprit, autrefois amoureux de la lutte,
# L'Espoir, dont l'éperon attisait ton ardeur,
# Ne veut plus t'enfourcher! Couche-toi sans pudeur,
# Vieux cheval dont le pied à chaque obstacle bute.
# Résigne-toi, mon coeur; dors ton sommeil de brute.
#
# [The file has been closed.]
#
# [The finally area always runs. Exception or not. Ok!.]

# %%
# 5 "Mission critical" variables [making sure x is there]
# and notice testing the variables: ValueError and ZeroDivisionError

y = float(input("Enter a float: "))
print("reciprocal is ",1/y)
# ----------------------------------
status_msg = ""
try:
    x = float(input("Enter a number: "))
    print("\tThe reciprocal is ", 1/x)

except ValueError:
    # in case the user enters a letter
    # this is an example of a _specific_ error
    print("Sorry, only numbers, please.")

except ZeroDivisionError:
    # this is an example of a _specific_ error
    print("Sorry, no reciprocal for 0.")

except:
    # this is an example of a _general_ error
    # something else went wrong.
    print("Sorry, there was an error.  Contact Rob.")

else: # never gonna print - but finally would!
    status_msg = "All good."
    #print("\nThis is the else section - called no matter what.")

print(status_msg)
# Out:
# Enter a float: 7
# reciprocal is  0.14285714285714285
# Enter a number: x
# Sorry, only numbers, please.

# %%
# 6: define Python user-defined exceptions
# in this example we want to make sure that the 
# user's input is okay ... notice "raise"

class InvalidAgeException(Exception):
    "Raised when the input value is less than 18"
    # here we could save to a log or send a message.
    pass

# you need to guess this number
number = 18

try:
    input_num = int(input("Enter a number: "))
    if input_num < number:
        raise InvalidAgeException
    else:
        print("Eligible to Vote")
        
except InvalidAgeException:
    print("Exception occurred: Invalid Age")

# %%
# 6a: same idea but in object-oriented code.
# in this example, only students 18-25 get the discount.

class InvalidAgeException(Exception):
    """Exception raised for errors in the input age.

    Attributes:
        age -- input age which caused the error
        message -- explanation of the error
    """

    def __init__(self, age, message="Discounts only for students under 25 (18 - 25)"):
        self.age = age
        self.message = message
        super().__init__(self.message)


age = int(input("Enter your age: "))
if not 18 < age < 25:
    raise InvalidAgeException(age)

# %% [markdown]
# <hr />
# <h2 style="background-color: #003262; color:white; border-radius: 4px; padding: 8px;">
# Lambda and Map()
# </h2>

# %% [markdown]
# <img src="images/mapsyntax.jpg">
# <p>In the first pass, the value of <code>x</code> is taken from the iterable (here 23) and passed to the middle x.</p>
# <p>
# The lambda says to declare a placeholder variable x.
# </p><p>
# Repeat until the iterable is exhausted.</p>

# %% [markdown]
# <hr/>
# <p>
# <img src="images/AdvancedIcon.png" style="width:50px;padding-right:10px;float:left;">
# After list comprehensions what can we do to pass data (very much like a list comprehension) that&rsquo;ll build up to bigger containers? Hence <code>lambda</code> - an anonymous function and <code>map</code>.</p>
# <p>The syntax is straight forward: a placeholder variable separated by a colon : and then the action.</p>
# <p>A <code>lambda</code> is a small, anonymous function, taking any number of arguments but can have only <u>one</u> expression.  The syntax is <code>lambda <i>arguments</i> : <i>expression</i></code>.</p>
# <p>Notice the "placeholder" variable in the middle of the statement, the actions upon (expression) upon that variable.  The lambda acts like the "eval()" function in some languages.</p>
# <p style="border-radius:3px;background-color:steelblue;padding:5px;color:white;">Read each of the below statements and think about how they're read by the computer and where the "temp" variable is declared and initialized.</p>

# %% [markdown]
# <h2 style="color: #3B7EA1;">One variable</h2>

# %%
# one var 
def x(i):
    return i + 10

""" In the stack there must be a reference for ever 
for this function ... """

x = lambda a : a + 10
print(x)
print(x(5))
""" this lives on the heap and will disappear from RAM after use. 
"""
# Out:
# <function <lambda> at 0x10671f060>
# 15
# ' this lives on the heap and will disappear from RAM after use. \n'

# %% [markdown]
# <h2  style="color: #3B7EA1;">Two Variables</h2>

# %%
# two vars:
total = lambda a, b : a + b
print(total(20,15))

# lambda accepting 3 vars and adding them 
x = lambda a, b, c : a + b + c
print(x(10, 25, 33))

# notice here number1[0] is added to number2[0] and so on
number1 = [5,10,15]
number2 = [6, 12, 18]

print(type(number2))

result = map(lambda x, y: x + y, number1, number2)

print(list(result))
# Out:
# <function <lambda> at 0x10671e200>
# 15
# 35
# 68
# <class 'list'>
# [11, 22, 33]

# %% [markdown]
# <h2  style="color: #3B7EA1;">Lambda in a function</h2>

# %%
def get_rate(currency):
    rates = {"EUR": .85, "CND": 1.23}
    return rates[currency]

def todays_rates(n):
    return lambda a : a * n

my_euros = todays_rates( get_rate("EUR") )

money_to_convert = int(input("Enter the whole number amount: $: "))

print(f"€{my_euros(money_to_convert)}")

# ---------------------------------
import decimal

inputNumber = my_euros(money_to_convert)
decimalVersion = decimal.Decimal(inputNumber)
roundedVersion = decimalVersion.quantize(decimal.Decimal('0.00'))

print("€",roundedVersion)
# Out:
# Enter the whole number amount: $: 42
# €35.699999999999996
# € 35.70

# %% [markdown]
# <hr />
# <h2 style="color: #3B7EA1;">Map and Lambda</h2>
# <p><code>map()</code> executes a specified function for each element in an iterable.</p><p>The syntax is <code>map(<i>function</i>, <i>iterable</i></code>.)
# </p>
# <p>Here we define a function that accepts a single parameter and returns the length of that parameter.  The next example passes two iterables.  Think of <code>map()</code> as your own hands - getting the first value from the iterable and passing it into the placeholder variable x that lambda will use.</p>

# %%
list(map(lambda x : x**2, (5, 10, 15, 20)))
# Out:
# [25, 100, 225, 400]

# %%
# the map command takes each element from the list () and passes 
# them one-by-one to the function (whoIsLonger()).  The results
# are still in RAM, so let's send them to a list for printing.

def whoIsLonger(n):
    return len(n)

x = map(whoIsLonger, ('Boston','Berkeley','Roma', 'Juan-les-Pins'))
print(list(x))
# Out:
# [6, 8, 4, 13]

# %%
# LAMBDA with single var input to iterate over
numbers = (9, 8, 7, 6)
result = map(lambda x: x + x, numbers)
print(list(result))

# OUTPUT: [18, 16, 14, 12]

# LAMBDA with more than 1 object
number1 = [5, 10, 15]
number2 = [6, 12, 18]

result = map(lambda x,y : x+y, number1, number2)
print(list(result))

# OUTPUT: [11, 22, 33]
# Out:
# [18, 16, 14, 12]
# [11, 22, 33]

# %%
# do the same thing different ways
# MAP
def addition(n):
    return n + n
    
numbers = (1, 2, 3, 4)
result = map(addition, numbers)
print(result)
print(list(result))

# try with strings
def additionS(s1, s2):
    return s1 + s2

x = map(additionS, ["Boston", "BackBay", "Cambridge"], ["3000","3000","1203"])
print(x)  # notice this is a map object - 
# need to cast into something usable.

converted_x_to_list = list(x)
print(converted_x_to_list)
# Out:
# <map object at 0x1087203a0>
# [2, 4, 6, 8]
# <map object at 0x108609090>
# ['Boston3000', 'BackBay3000', 'Cambridge1203']

# %% [markdown]
# <hr />
# <p style="background-color: #003262; color:white; border-radius: 4px; padding: 8px; font-size:24px;">Breakout Room
# </p>
# <a href="week_05_activity_solution.ipynb

# %% [markdown]
# <ol>
# <li><a href="week_05_activity.ipynb" target="new">Activity</a></li>
# <li><a href="week_05_activity_solution.ipynb" target="new">Solution</a></li>
# <li><a href="week_5_howtos.ipynb" target="new">Optional extras: how to...</a></li>
# <li><a href="week_05_functions_intro_extra.ipynb">Optional extras about functions</a></li>
# </ol>

# %% [markdown]
# <hr />
# <div style="background-color:#C4820E;color:white; padding:5px;">
#     <strong>Appendix</strong>: Optional: Appendix about handling errors: assert, DEBUG, *arg and **kwarg &amp; logging errors.</div>
# </p>

# %% [markdown]
# <p>There are several ways to handle errors, depending on the programming language:
#     <ol style="line-height:18px;">
#         <li><code>assert</code>: a very python way.  This way we can separate data from coding, cause we know what the data should be (e.g., x + y = <i>2</i>) in order to focus on the coding</li>
#     <li>constant, e.g., a global boolean value <code>DEBUG = True</code> one way of using if statements during development</li>
#         <li>Using <i>default values</i> </li>
#         <li><code>try ... except</code> blocks; described below in the lesson</li>
#         <li><i>*arg</i> and <i>**kwarg</i></li>
#         <li><code>logging</code> described in the Appendix
#     </ol>
# </p>
# <p>One way to avoid errors is to pass a default value - that way a variable in a function doesn&rsquo;t have to be tested and the code reliably has data to use.</p>
# <p>Another way to avoid errors is when passing parameters to apply the idea of <i>polymorphism</i>: using the <code>*arg</code> and <code>**kwarg</code> to pass an unknown number of items (aka <i>positional arguments</i>)</p>
# <p>See Examples <a href="#appendix">Appendix</a> below for python&rsquo;s <code>logging</code></p>

# %% [markdown]
# <code>DEBUG = True</code><br />
# <code>assert</code><br />
# <code>logger</code><br />
# <code>*args</code><br />
# <code>**kwargs</code><br />
# <p>Use error checking (1) error correction on input, (2) critical running of your script (something that must be there or else!), (3) always use try/except around any file read/write, SQL connection, URL, etc., (4) accidents in math/missing values</p>
# <p><b>Boolean flag - debug idea</b></p>
# <pre style="color:olive;">DEBUG = True
# ...
# if DEBUG:
#     results = call_function_x()
# else:
#     results = call_other_function()
#
# print(f"The test version results are {results}")
# </pre>
# <hr />
# <p><b>Assert</b></p>
# <pre style="color:black;">from nose.tools import assert_equal
#
# def test(num):
#     """ Returns the sum of all the digits of the input """
#     returnTest = num + 5
#     return returnTest
#
# assert_equal(test(10), 15)
#
# print(test(55) == 12)  # for error checking - like a range of data.
# </pre>
#
# <hr />
# <p><b>Logging</b><br />and types of errors: debug, info, warning, error, critical.  Code usually continues running if <i>debug</i>, <i>info</i>, <i>warning</i>; but will crash on <i>error</i> and <i>critical</i>.</p>

# %% [markdown]
# <hr /><b>Default values in parameters</b>
# <pre>
# def myfunction(name = "Tom"):
#     print(f"Welcome, {name}")
#
# myfunction("Rex")
# myfunction()</pre>

# %% [markdown]
# <hr />
# <b>*arg and **kwarg</b>
# <ul>
#     <li>
#         <code>*args</code> is used to unpack a list. "args" is just a name - call it anything you want. The * is used to pass "positional arguments" - that is, not a copy of the full list, but a way to iterate over the positions (0, 1, 2, ... n) to get each element.
#     </li>
#     <li>
#         <code>**kwarg</code> is for unpacking dictionaries
#     </li>
# </ul>
# <p><b>*arg Example</b></p>

# %%
# *args is an unpacking operator.

l1 = [1, 2, 3, 4, 5, 6]
g = 1,2,3
#print(l1)

winner = 3

#def sumset(para1, param2) ...
#def sumset(give me the list)
def sumset(*args):  # NAME doesn't matter - use *cats if you want!
    summer = 0
    #some other important data is here for checking ... 
    for x in args:
        summer += x
        print(f"Sumset x = {x}. summer = {summer}")
    return summer

# %%
print("\nSumset with list: ", sumset(*l1)) 

print("\nSumset with hardcoded list:", sumset(1, 2, 3)) 
# will work fine.

print(sumset(l1[0]))

#but not using the * to indicate unpacking will fail.
#print(sumset(l1)) # will fail.
# Out:
# Sumset x = 1. summer = 1
# Sumset x = 2. summer = 3
# Sumset x = 3. summer = 6
# Sumset x = 4. summer = 10
# Sumset x = 5. summer = 15
# Sumset x = 6. summer = 21
#
# Sumset with list:  21
# Sumset x = 1. summer = 1
# Sumset x = 2. summer = 3
# Sumset x = 3. summer = 6
#
# Sumset with hardcoded list: 6
# Sumset x = 1. summer = 1
# 1

# %%
# Passing a list of hard-coded names and selecting 
# only #2 in unknown list.
guests = ["Tom", "Rex", "Suky", "Lars", "Jane", "Shuo"]
print(type(guests))

def invitations(*guests):
    print("Who has arrived? ", guests[2])

invitations("Tom", "Rex", "Suky", "Lars")
# Out:
# <class 'list'>
# Who has arrived?  Suky

# %% [markdown]
# <p><b>**kwarg Example</b> is used with dictionaries; if you don't know how many arguments will be used, use **</p>

# %%
def invitations(**people):
    print("Today's host is " + people["host"])

invitations(dj = "Tom", host = "Rex")
# Out:
# Today's host is Rex

# %%
dtest = {"1":"cat", "2":"dog"}
print(type(dtest))

print("\nGETTING VALUES")

def dtester(**kwargs):
    v = ""
    for i in kwargs.values():
        v += " "+i
    return v

print(dtester(**dtest))
# Out:
# <class 'dict'>
#
# GETTING VALUES
#  cat dog

# %%
print("GETTING KEYS")
dtest = {"1":"cat", "2":"dog"}
print(type(dtest))

def dtester(**kwargs):
    v = ""
    for i in kwargs:
        v += " "+i
    return v

print(dtester(**dtest))
# Out:
# GETTING KEYS
# <class 'dict'>
#  1 2

# %% [markdown]
# <hr />
# <h2 style="color: #3B7EA1;">Logging</h2>
# <b>A note about errors and debugging</b>
# <p>Consider hardcoding values first in order to focus on the logic of your script.  Once the logic seems solid (using the assert is a good idea here), now variabilize your code - removing the hard coded test values.  e.g., make sure that your addition function returns a correct value (2 + 2 ≠ 5) ... then you can replace vars (i + j = 4).</p>
# <p>There are 5 levels of errors: debug | info | Warning | Error | Critical.   Optional later: check out the <code>import logging</code> library and set for yourself the level of bugs to catch.</p>
# <pre>
# import logging
#
# #create a logger
# logger = logging.getLogger('mylogger')
# #set logging level - see the options:
# logger.setLevel(logging.DEBUG)
#
# handler = logging.FileHandler('mylog.log')
# #create a logging format
# formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
# handler.setFormatter(formatter)
# logger.addHandler(handler)
#
# #write a debug message
# logger.debug('This is a DEBUG message')
# </pre>
# <p>And then you can scan the file for error message and determine which to keep, which to show the end-user, and which of them need to be integrated into your try-except blocks.</p>
# <hr />
# <h3>Example</h3>

# %%
""" from https://pythonexamples.org/python-logging-debug/ """
import logging

class MyFilter(object):
    def __init__(self, level):
        self.__level = level

    def filter(self, logRecord):
        return logRecord.levelno <= self.__level

#create a logger
logger = logging.getLogger('mylogger')
logger.setLevel(logging.DEBUG)
handler = logging.FileHandler('mylog.log')
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
#set filter to log only DEBUG lines
handler.addFilter(MyFilter(logging.DEBUG))
logger.addHandler(handler)

#write a debug line to log file
logger.debug('This is a DEBUG message')
logger.info('This is a INFO message')
logger.warning('This is a WARNING message')
logger.error('This is an ERROR message')
logger.critical('This is a CRITICAL message')

# %% [markdown]
# <hr />
# <p>End of the optional and review materials.</p>
