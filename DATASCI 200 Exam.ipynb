# %%
import numpy as np
np.random.seed(25)
ar = np.random.randn(1000)
ar = ar * 100
ar = ar.astype('int8')
ar = ar.reshape((200, 5))

# %%
ar
# Out:
# array([[  22,  102,  -83,  -59,  -95],
#        [ -22,  -61,  -73,   51,   86],
#        [ -92,  -23,  -41,  123,    7],
#        [-124,  120, -104,  105,  -41],
#        [ -27,   -3,   26,   68,   99],
#        [  59,   53,  -29,  -51,  -58],
#        [  22,   73,  -96,   38,   39],
#        [  40,   21,  -63,   24,   63],
#        [  11,   68,   24,  -70,   36],
#        [ -50,  -22,  -56,   10,  -55],
#        [ 109,  -90,  -62,  -94,  117],
#        [ -37,  -54,   28,  -20,  118],
#        [  72,  -22,   94,   31, -116],
#        [  31,   47,   57,   50,  -62],
#        [ -34,   50,   76,  112,   16],
#        [ -96,   49,  -55,   -8,  -60],
#        [  -6,  -85,   42,  -27,  119],
#        [  -9,   83,  -78,  104,  -64],
#        [  67,   -9,  121,   49, -114],
#        [ -53,  -91,  -21,   19,  -32],
#        [  84,   76,   44,   43,  102],
#        [ -58,    4,   56, -114,    0],
#        [ -29,   23,   67,  122,  -60],
#        [ -16,  -65,  -19,   17,    3],
# ...

# %%
ar.min()
# Out:
# -128

# %%
ar.max()
# Out:
# 127

# %%
ar.mean()
# Out:
# -0.791

# %%
ar[7][1]
# Out:
# 21

# %%
counter = 0
for row in ar:
    for num in row:
        if num > ar.mean():
            counter += 1
print(counter)
# Out:
# 506

# %%
theSum = 0
for row in ar:
    for num in row:
        if num > -5 and num <= 20:
            theSum += num
print(theSum)
# Out:
# 748

# %%
rowNum = 0
colNum = 0
for row in ar:
    for num in row:
        if num == ar.max():
            print(num)
            print(rowNum, colNum)
        else:
            colNum += 1
    rowNum += 1
    colNum = 0
print(rowNum, colNum)
# Out:
# 127
# 199 4
# 200 0

# %%
ar.max()
# Out:
# 127

# %%
data = pd.read_csv("2019_production_reports.csv")
# Out:
# C:\Users\aruna\AppData\Local\Temp\ipykernel_25824\1153224148.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("2019_production_reports.csv")

# %%
data
# Out:
#         Unnamed: 0 report_date  state_code  api_county_code  api_seq_num  \
# 0                0      1/2000           5               43         6112
# 1                1      1/2000           5               67         7833
# 2                2      1/2000           5               75         6127
# 3                3      1/2000           5               81         5515
# 4                4      1/2001           5                1         7217
# ...            ...         ...         ...              ...          ...
# 843498      843498     12/2019           5              123        33999
# 843499      843499     12/2019           5              123        34000
# 843500      843500     12/2019           5              123        34011
# 843501      843501     12/2019           5              123        34137
# 843502      843502     12/2019           5              123        38290
#
#         sidetrack_num formation_code well_status  prod_days water_disp_code  \
# ...

# %%
data[['month', 'year']] = data['report_date'].str.split('/', n=1, expand=True)
data
# Out:
#         Unnamed: 0 report_date  state_code  api_county_code  api_seq_num  \
# 0                0      1/2000           5               43         6112
# 1                1      1/2000           5               67         7833
# 2                2      1/2000           5               75         6127
# 3                3      1/2000           5               81         5515
# 4                4      1/2001           5                1         7217
# ...            ...         ...         ...              ...          ...
# 843498      843498     12/2019           5              123        33999
# 843499      843499     12/2019           5              123        34000
# 843500      843500     12/2019           5              123        34011
# 843501      843501     12/2019           5              123        34137
# 843502      843502     12/2019           5              123        38290
#
#         sidetrack_num formation_code well_status  prod_days water_disp_code  \
# ...

# %%
# selecting rows based on condition 
rslt_df = data[data['year'] == '2019'] 

print('\nResult dataframe :\n', rslt_df)
# Out:
# Result dataframe :
#          Unnamed: 0 report_date  state_code  api_county_code  api_seq_num  \
# 2753          2753      1/2019           5                1         5534
# 2754          2754      1/2019           5                1         5545
# 2755          2755      1/2019           5                1         6060
# 2756          2756      1/2019           5                1         6072
# 2757          2757      1/2019           5                1         6142
# ...            ...         ...         ...              ...          ...
# 843498      843498     12/2019           5              123        33999
# 843499      843499     12/2019           5              123        34000
# 843500      843500     12/2019           5              123        34011
# 843501      843501     12/2019           5              123        34137
# 843502      843502     12/2019           5              123        38290
#
# ...

# %%
dff = rslt_df.groupby(["SINID","EXTRA"]).MONTREGL.sum().reset_index()

# %%
df1 = rslt_df.groupby(["month"]).sum()
# Out:
# C:\Users\aruna\AppData\Local\Temp\ipykernel_25824\1408912582.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = rslt_df.groupby(["month"]).sum()

# %%
df1[['oil_vol']]
# Out:
#           oil_vol
# month
# 1      15637679.0
# 10     11248098.0
# 11        63855.0
# 12            0.0
# 2      14086097.0
# 3      14899879.0
# 4      14929324.0
# 5      15829398.0
# 6      15790648.0
# 7      15984551.0
# 8      16381295.0
# 9      15722050.0

# %%
subset = rslt_df[['operator_num','gas_prod']]

# %%
df2 = subset.groupby(["operator_num"]).sum()

# %%
df2.max()
# Out:
# gas_prod    378308172.0
# dtype: float64

# %%
df2.sort_values(by=['gas_prod'])
# Out:
#                  gas_prod
# operator_num
# 10675                 0.0
# 10492                 0.0
# 10491                 0.0
# 10489                 0.0
# 10484                 0.0
# ...                   ...
# 10000         135135165.0
# 10456         143607481.0
# 96850         201937808.0
# 47120         230061231.0
# 46685         378308172.0
#
# [297 rows x 1 columns]

# %%
subset = rslt_df[['flared']]

# %%
subset
# Out:
#         flared
# 2753       NaN
# 2754       NaN
# 2755     284.0
# 2756       NaN
# 2757       NaN
# ...        ...
# 843498     NaN
# 843499     NaN
# 843500     NaN
# 843501     NaN
# 843502     NaN
#
# [592091 rows x 1 columns]

# %%
subset.sum()
# Out:
# flared    3963411.0
# dtype: float64

# %% [markdown]
# In 2019, what was the average total gas production from all gas wells per day? (Answer as a single integer: the average gas production rounded up to the nearest whole number)

# %%
rslt_df.columns
# Out:
# Index(['Unnamed: 0', 'report_date', 'state_code', 'api_county_code',
#        'api_seq_num', 'sidetrack_num', 'formation_code', 'well_status',
#        'prod_days', 'water_disp_code', 'water_vol', 'water_press_tbg',
#        'water_press_csg', 'bom_invent', 'oil_vol', 'oil_sales', 'adjustment',
#        'eom_invent', 'gravity_sales', 'gas_sales', 'flared', 'gas_vol',
#        'shrink', 'gas_prod', 'btu_sales', 'gas_press_tbg', 'gas_press_csg',
#        'operator_num', 'name', 'facility_name', 'facility_num',
#        'accepted_date', 'revised', 'month', 'year'],
#       dtype='object')

# %%
subset = rslt_df[['prod_days','gas_prod', 'month','facility_name', 'facility_num']]

# %%
subset
# Out:
#         prod_days  gas_prod month    facility_name facility_num
# 2753         31.0       NaN     1          COORDES            3
# 2754          0.0       NaN     1          COORDES            4
# 2755         31.0     292.0     1     JOLLY-PLATTS            2
# 2756          NaN       NaN     1              JAN            1
# 2757          NaN       NaN     1  UPRR-SANDEN-EHN       17-Feb
# ...           ...       ...   ...              ...          ...
# 843498        0.0       NaN    12     392 VENTURES       21-22D
# 843499        0.0       NaN    12     392 VENTURES         22CD
# 843500        0.0       NaN    12     392 VENTURES       42-22D
# 843501        0.0       NaN    12     392 VENTURES         22JD
# 843502        0.0       NaN    12   State Antelope        34-24
#
# [592091 rows x 5 columns]

# %%
newdf = subset[subset['prod_days'] > 0]

# %%
newdf['per_day'] = newdf['gas_prod']/newdf['prod_days']
# Out:
# C:\Users\aruna\AppData\Local\Temp\ipykernel_25824\4202814630.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['per_day'] = newdf['gas_prod']/newdf['prod_days']

# %%
newdf
# Out:
#         prod_days  gas_prod month        facility_name facility_num    per_day
# 2753         31.0       NaN     1              COORDES            3        NaN
# 2755         31.0     292.0     1         JOLLY-PLATTS            2   9.419355
# 2759         31.0       NaN     1                  EHN       20-Apr        NaN
# 2760         31.0     341.0     1             N QUEBEC            1  11.000000
# 2763         10.0      30.0     1  STATE OF COLORADO P            3   3.000000
# ...           ...       ...   ...                  ...          ...        ...
# 825420       30.0       NaN    11                  NGL          C2C        NaN
# 825421       30.0       NaN    11                  EWS           4A        NaN
# 825422       30.0       NaN    11                  EWS           6B        NaN
# 825425       30.0     290.0    11               FHA 22            3   9.666667
# 825426       30.0     179.0    11                 WELP        24-13   5.966667
#
# ...

# %%
df2 = newdf.groupby(["month"]).sum()
# Out:
# C:\Users\aruna\AppData\Local\Temp\ipykernel_25824\743680619.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = newdf.groupby(["month"]).sum()

# %%
df2
# Out:
#        prod_days     gas_prod       per_day
# month
# 1      1258599.0  210304537.0  7.088822e+06
# 10     1032790.0  182874754.0  6.204624e+06
# 11       12491.0     601436.0  2.056902e+04
# 2      1113682.0  188396111.0  7.043116e+06
# 3      1247120.0  209767819.0  8.548463e+06
# 4      1224880.0  204438897.0  7.125536e+06
# 5      1242810.0  210228604.0  7.154090e+06
# 6      1218653.0  203153012.0  7.131202e+06
# 7      1246401.0  207396491.0  7.072120e+06
# 8      1223181.0  207449493.0  7.128981e+06
# 9      1121527.0  197041458.0  7.043371e+06

# %%
newdf['per_day'].mean()
# Out:
# 175.4214322813523

# %%
newdf['per_day'].sum()
# Out:
# 71560892.82055801

# %% [markdown]
# In 2019, what county had the most oil & gas wells operating? (Answer as a single integer: the API county code)

# %%
subset = rslt_df[['api_county_code','well_status', 'month','facility_name', 'facility_num']]

# %%
subset
# Out:
#         api_county_code well_status month    facility_name facility_num
# 2753                  1          PR     1          COORDES            3
# 2754                  1          SI     1          COORDES            4
# 2755                  1          PR     1     JOLLY-PLATTS            2
# 2756                  1          SI     1              JAN            1
# 2757                  1          SI     1  UPRR-SANDEN-EHN       17-Feb
# ...                 ...         ...   ...              ...          ...
# 843498              123          PA    12     392 VENTURES       21-22D
# 843499              123          PA    12     392 VENTURES         22CD
# 843500              123          PA    12     392 VENTURES       42-22D
# 843501              123          PA    12     392 VENTURES         22JD
# 843502              123          SI    12   State Antelope        34-24
#
# [592091 rows x 5 columns]

# %%
set(subset.well_status.values)
# Out:
# {'AB', 'DG', 'IJ', 'PA', 'PR', 'SI', 'TA', 'WO', 'si'}

# %%
newdf = subset[subset['well_status'] == 'PR']
newdf
# Out:
#         api_county_code well_status month        facility_name facility_num
# 2753                  1          PR     1              COORDES            3
# 2755                  1          PR     1         JOLLY-PLATTS            2
# 2759                  1          PR     1                  EHN       20-Apr
# 2760                  1          PR     1             N QUEBEC            1
# 2763                  1          PR     1  STATE OF COLORADO P            3
# ...                 ...         ...   ...                  ...          ...
# 825402              123          PR    11           MOYER UNIT       Jun-32
# 825405              123          PR    11                DOWDY            1
# 825407              123          PR    11              WOOLLEY            2
# 825425              125          PR    11               FHA 22            3
# 825426              125          PR    11                 WELP        24-13
#
# [419429 rows x 5 columns]

# %%
newdf['counter'] = 1
# Out:
# C:\Users\aruna\AppData\Local\Temp\ipykernel_25824\1855252074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['counter'] = 1

# %%
newdf.head(50)
# Out:
#       api_county_code well_status month         facility_name facility_num  \
# 2753                1          PR     1               COORDES            3
# 2755                1          PR     1          JOLLY-PLATTS            2
# 2759                1          PR     1                   EHN       20-Apr
# 2760                1          PR     1              N QUEBEC            1
# 2763                1          PR     1   STATE OF COLORADO P            3
# 2767                1          PR     1              FERGUSON       25-Jun
# 2768                1          PR     1               BRUCHEZ            1
# 2772                1          PR     1               COLLINS        14-20
# 2790                1          PR     1      UPRR 23 PAN AM G            1
# 2792                1          PR     1     HAAKE FRMS INC GU            1
# 2797                1          PR     1              ZARLENGO            2
# ...

# %%
df = newdf.drop_duplicates(subset=["api_county_code", "facility_name", "facility_num"])
df
# Out:
#         api_county_code well_status month        facility_name facility_num  \
# 2753                  1          PR     1              COORDES            3
# 2755                  1          PR     1         JOLLY-PLATTS            2
# 2759                  1          PR     1                  EHN       20-Apr
# 2760                  1          PR     1             N QUEBEC            1
# 2763                  1          PR     1  STATE OF COLORADO P            3
# ...                 ...         ...   ...                  ...          ...
# 806736              123          PR    10              Bighorn  4I-17H-P267
# 807136              123          PR    10            Wilmoth E       5A-202
# 807137              123          PR    10            Wilmoth W       5A-304
# 807138              123          PR    10            Wilmoth W       5A-204
# 807139              123          PR    10            Wilmoth E       5A-302
#
#         counter
# 2753          1
# 2755          1
# ...

# %%
df3 = df.groupby("api_county_code").sum()
# Out:
# C:\Users\aruna\AppData\Local\Temp\ipykernel_25824\4199529731.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3 = df.groupby("api_county_code").sum()

# %%
df3.sort_values(by=['counter'])
# Out:
#                  counter
# api_county_code
# 29                     2
# 63                     8
# 115                   11
# 11                    22
# 99                    23
# 33                    24
# 107                   25
# 39                    31
# 51                    32
# 55                    34
# 87                    58
# 43                    59
# 14                    64
# 75                    77
# 9                     87
# 73                    90
# 61                    90
# 113                   94
# 83                   101
# 7                    109
# 69                   124
# 5                    125
# 57                   133
# 13                   262
# 95                   263
# 17                   288
# 121                  358
# 81                   401
# 1                    529
# 77                  1083
# 103                 2161
# 71                  2682
# 67                  2946
# 125                 3676
# 45                 11348
# ...

# %%
df2 = newdf.groupby(["api_county_code", "facility_name", "facility_num"]).sum()
# Out:
# C:\Users\aruna\AppData\Local\Temp\ipykernel_25824\3589253383.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = newdf.groupby(["api_county_code", "facility_name", "facility_num"]).sum()

# %%
df2
# Out:
#                                                   counter
# api_county_code facility_name       facility_num
# 1               (UPRR) WAGNER       19-Dec              4
#                 ABBOTT              14-Dec              5
#                                     14-Nov              5
#                                     43-10               5
#                 ABBOTT  LANDS  32-7 4                   2
# ...                                                   ...
# 125             ZUEGE*ALLEN         8-Jan               9
#                 ZWIRN               14-32 1S43W        10
#                                     21-10               6
#                                     23-32 1S43W        10
#                 Zwirn               31-32 1S43W        10
#
# [42552 rows x 1 columns]
