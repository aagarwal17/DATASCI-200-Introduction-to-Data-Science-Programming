# %% [markdown]
# <p style="font-size:9px;">Version: Discussion version 1,
#     July 18, 2023 | Updated Oct 14, 2023: <b>Oct 17, 2023</b> [&copy; 2023 gb]</p>
# <img src="images/ischool-banner.png" />
# <p>&nbsp;</p>
# <div style="height: 50px;color:#3B7EA1; font-size:24px; vertical-align:top; text-align:left;">
#     Computing for Data Science
#     <img style="width:20%; vertical-align:top; float: left; padding-right: 20px; display: block; margin-left: 0; margin-right: auto;"
#          src="images/ucb_logo.png"/>
# </div>
# <hr />
# <h1 style="font-size:32; color: #003262;">Weekly Syllabus Topics: Week 8</h1>
# <table width="100%;">
# <tr>
# <td style="text-align:left; vertical-align:top;">
# <ol>
#     <li>
#     <ul>
#         <li>Computer Architecture Basics;
#         Bash, Git, GitHub;</li>
#         <li>Command Line;</li>
#         <li>Manipulating Files &amp; Directories;
#         VIM;
#         Command Line intro;</li>
#     </ul>
# </li>
# <li>
#     <ul>
#     <li>Programming Lang Orientation:
#     <li>jupyter; python and command line;
#     objects &amp; types;
#     <li>variables (numbers and strings), formatting strings;</li>
#     <li>control while loops</li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Sequences</li>
#         <li>Lists, Tuples &amp; Mutability</li>
#         <li>Ranges</li>
#         <li>Dictionaries, Nested Lists &amp; dictionaries</li>
#     </ul>
# </li>
# </ol>
# </td>
# <td style="text-align:left; vertical-align:top;">
# <ol start="4">
# <li>
#     <ul>
#         <li>For Loops
#         <li>Exits
#         <li>Algorithms: searching [exhaustive, bisection, heron&rsquo;s methods]</li>
#         <li>Comprehensions</li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Functions</li>
#         <li>Calling, Nesting</li>
#         <li>Namespaces, Global and Local Vars</li>
#         <li>Recursion; nested dictionaries &amp; recursion</li>
#         <li>Parameters</li>
#         <li>Exceptions</li>
#         <li>Lambdas</li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Complexity
#         <li>Measuring time and Steps</li>
#         <li>Big &Theta;</li>
#         <li>Searching and Subsequences
#         <li>Modules &amp; Packages</li>
#     </ul>
# </li>
# </ol>
# </td>
#     </tr>
# <table>
# <table width="100%">
#     <tr>
# <td style="text-align:left; vertical-align:top;">
# <ol start="7">
# <li>
#     <ul>
#         <li>Classes</li>
#         <li>Attributes, Binding</li>
#         <li>Initializing and Control</li>
#         <li>&UnderBar;&UnderBar;str&UnderBar;&UnderBar; and &UnderBar;&UnderBar;repr&UnderBar;&UnderBar;
#         </li>
#     </ul>
# </li>
# <li>
#     <ul  style='background-color: #FDB515;'>
#         <li>Object-Oriented Programming</li>
#         <li>Inheritance</li>
#         <li>Polymorphism</li>
#         <li>Magic Methods</li>
#     </ul>
# </li>
# <li>
#     <ul>
#     <li>PyData Ecosystem and Numpy</li>
#     <li>Boolean selection and types</li>
#     <li>Vectorization &amp; Multidimensional Arrays</li>
#     <li>Slicing and combining</li>
#     <li>Linear model in matrix form, Numpy</li>
#     </ul>
# </li>
# </ol>
# </td>
# <td style="text-align:left; vertical-align:top;">
# <ol start="10">
# <li>
#     <ul>
#         <li>Pandas &amp; Data Analysis</li>
#         <li>Series and Data Frames</li>
#         <li>Bracket index, log &amp; iloc</li>
#         <li>Functions and DataFrames</li>
#         <li>Sorting</li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Datasets and EDA</li>
#         <li>Fixing Data Issues (Cleansing)</li>
#         <li>Answering Questions</li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Plotting &amp; Visualization</li>
#         <li>Libraries (Matplotlib, Seaborn, etc.)</li>
#         <li>Plot features</li>
#     </ul>
# </li>
# </ol>
# </td>
# </tr>
# </table>
# <table width="100%">
# <tr>
# <td style="text-align:left; vertical-align:top;">
# <ol start="13">
#     <li>
#     <ul>
#         <li>Pandas Aggregation &amp; Group Operations</li>
#         <li>Series.groupby</li>
#         <li>DataFrame.groupby</li>
#         <li>Aggregation</li>
#         <li>Pivot Tables &amp; Crosstabs</li>
#     </ul>
# </li>
# <li>
#     <ul>
#         <li>Presentations (so no time to cover...
#         <li>Texts, unicode, decoding errors, regex, time series, etc.)</li>
#     </ul>
# </li>
# </ol>
# </td>
# </tr>
# </table>
#     <p>
#         <img src="images/IntroIcon.png" style="float:left; padding:10px; width:50px; text-align:top;"/>
#         <span  style="color: #3B7EA1;font-size:24px;">Introduction</span>
#     </p>
#     <p>The themes from the asynch part of the week&rsquo;s lesson include Intro to OOP, Inheritance, Polymorphism, Magic Methods, and increased use in libraries, such as numpy.<p>
# <p>For the live component, we review the main points and apply them in different code examples.  Be sure to <b>review</b> last week&rsquo;s presentation of get/set methods and property decorators!</p>
# <ul>
#     <li>Part 1: Encapsulation, Inheritence, and Polymorphism: Parent Classes, child Classes; use of <code>__init__</code> and <code>__super__</code>
#         <ol>
#             <li>Example 1: Coin toss (showing protected vars)</li>
#             <li>Example 2: Phone book (using pickle, constants)</li>
#             <li>Example 3: Introducing unicode, \N, last inheritance example</li>
#         </ol>
#     </li>
#     <li>Part 2: Magic Methods</li>
#     <li>Part 3: Static and Class Methods</li>
#     <li>Part 4: Demo OOP Application</li>
#     <li>Part 5: Optional Review of get/set, property() and @property</li>
# </ul>
# <hr />

# %% [markdown]
# <p style="background-color: #3B7EA1;font-size:18px; padding:10px; border-radius:4px; color:white;">As a way of briding into building our own classes: typical errors you&rsquo;ll encounter and using repr()</p>
# <p><b>1.</b>  Given this code block ... what kind of error(s) might you encounter? [there are 2].</p>
#     <blockquote>
# <pre>
# class Msg:
#     """ class for communicating messages/status to end-user """
#     def __init__(self):
#         self.comment = ""
#     def getComment():
#         return self.comment
#     def setComment(s):
#         self.comment = s
#
# """ other code here ...  """
# msg = Msg()
# msg.setMessage("Welcome")
# msg.getMessage()
# </pre>
# </blockquote>
# <hr />
# <p style="font-family: Courier; background-color:aluminum;color:black;font-size:12px;">
# Traceback (most recent call last):<br />
# File "/week_08/demo1.py", line 56, in &lt;module&gt;<br />
#     msg.setComment("Welcome!\n")<br />
# TypeError: Msg.setComment() takes 1 positional argument but 2 were given
# </p>
# <p style="font-family: serif;">The other error is similar:</p>
# <p style="font-family: Courier; background-color:aluminum;color:black;font-size:12px;">
# Traceback (most recent call last):
#   File "/week_08/demo1.py", line 61, in &lt;module&gt;
#     msg.getComment()
# TypeError: Msg.getComment() takes 0 positional arguments but 1 was given
# </p>
# <hr />
# <p style="font-size:14px;">How to fix it?</p>
# <pre>
# class Msg:
#     """ class for communicating messages/status to end-user """
#     def __init__(self):
#         self.comment = ""
#     def getComment(<span style="color:red;">self</span>):
#         return self.comment
#     def setComment(<span style="color:red;">self</span>, s):
#         self.comment = s
# </pre>
# </blockquote>
# <hr />
# <p><b>2.</b>  Can we add a <b>repr()</b>?  Yes.  Notice, too, the use of the base class Msg() and the <b>magic method</b> <code>__doc__</code></p>
# <blockquote>
# <pre>
# class Msg:
#     """ class for communicating messages/status to end-user """
#     def __init__(self):
#         self.comment = ""
#     def getComment(<span style="color:red;">self</span>):
#         return self.comment
#     def setComment(<span style="color:red;">self</span>, s):
#         self.comment = s
#     def __repr__(self):
#         return <span style="color:red;">Msg().__doc__</span><br />
# """ ... other code ... """
#
# print(msg.repr)
# </pre>
# </blockquote>

# %% [markdown]
# <h2 style="background-color: #003262; color:white; border-radius: 4px; padding: 8px;">
#     Inheritance
# </h2>
# <p>We start with the concept of the most stripped-down base class - a Person with a name.  Once defined as a parent class, we can apply the Person to child classes and to specific job needs, like &ldquo;Employee.&rdquo;</p>
# <p style="font-size:18px;">1.  The idea of inheritance means going <b>down</b> the hierarchical tree.</p>

# %%
class Person:
    def __init__(self, fname, lname):
        self.fname = fname
        self.lname = lname

    # as before, we want to get data out
    def getName(self):
        tempname = self.fname + " " + self.lname;
        return tempname
    
person = Person("Tom", "Jones")
print(f"Output: {person.getName()}")
# Out:
# Output: Tom Jones

# %% [markdown]
# <blockquote>
#     <p>When we think of inheritence, the direction, as it were, is from top <i>down</i> ... but the object-hierarchy allows also movement <i>up</i> the chain with <code>super</code>.
# </blockquote>
#
# <p style="padding:8px; background-color: pink; border-radius:3px;">Notice the differences between inherited classes with and without an __init__.</p>
# <p style="color:#003262;font-size:18px;">2a.  <b>A child class with <u>without</u> <code>__init__</code></b>.</p><p>  Notice the child class can pass the <i>parent</i> class as a parameter.  So even if our class is empty of methods and parameters, we still have access to those of the parent: (notice the <code>pass</code>)</p>

# %%
class Person:
    def __init__(self, fname, lname):
        self.fname = fname
        self.lname = lname

    # as before, we want to get data out
    def getName(self):
        tempname = self.fname + " " + self.lname;
        return tempname

class Child(Person):
    pass

child = Child("Matt", "Damon")  
child.getName()  # NOTE: in Jupyter Notebook, the output adds ' '
# Out:
# 'Matt Damon'

# %%
print(child.getName())  # in notebook, this technique lacks ' '
# Out:
# Matt Damon

# %% [markdown]
# <hr />
# <p style="font-size:18px;color:#003262;">2b: <b>A child class <u>with</u> an <code>__init__()</code></b> <u>overrides</u> the parent&rsquo;s __init__.</p>
# <p>Consequently, we must include the <code>self</code> in the constructor.</p>
# <p>Notice, too, that for the child we&rsquo;re using an additional parameter (age) - but since Parent doesn&rsquo;t use it, we pass only those it uses.</p>

# %%
class Person:
    def __init__(self, fname, lname):
        self.fname = fname
        self.lname = lname

    # as before, we want to get data out
    def getName(self):
        tempname = self.fname + " " + self.lname;
        return tempname


class Child(Person):
    def __init__(self, fname, lname, age):
        self.age = age
        Person.__init__(self, fname, lname)
        
c = Child("Mumin", "Khan", 24)
print(f"Output: {c.getName()}")
# Out:
# Output: Mumin Khan

# %% [markdown]
# <hr />
# <p style="font-size:18px;color:#003262;">2c.  <b>Adding methods <u>only</u> to the child</b> ...</p>
# <p>Note that in Child we inherit Parent; and we add self.age to Child.  Since Parent doesn&rsquo;t use it in its constructor, we can&rsquo;t pass it as a parameter but we can still use it in the child.   IMHO this emphasizes good modularization before coding.</p>

# %%
class Child(Person):
    def __init__(self, fname, lname, age):
        Person.__init__(self, fname, lname)
        self.age = age
        
    def get_age(self):
        return self.age
        
c = Child("Mumin", "Khan", 24)
print(c.getName())
c.get_age()
# Out:
# Mumin Khan
# 24

# %% [markdown]
# <hr />
# <p style="font-size:16px;">Reminder using the dot operator to get and set values.</p>

# %%
c.age = 25
c.get_age()
# Out:
# 25

# %% [markdown]
# <hr /><p style="font-size:18px;">Practice Suggestion: get/set &amp; decorators</p>
# <blockquote style="color:olive;">
#     <img style="float:left;width:50px;padding-right:10px;" src="images/DiscussIcon.png">
#     It&rsquo;s good practice here to create your own get/set methods and property decorators to control access to the data.  These minimalist examples provide a template for your own coding needs.  <b>Check out last week's optional get/set notebook</b>.</blockquote>
# <hr />

# %% [markdown]
# <hr />
# <p style="font-size:18px;">3.  <b>Going <u>up</u> the chain - using <code style="color:red;">super()</code></b> to gain all the properties of the parent.</p>
# <pre style='font-size:12px;'>
# class Person:
#     def __init__(self, fname, lname):
#         self.fname = fname
#         self.lname = lname
#
#     def getName(self):
#         tempname = self.fname + " " + self.lname;
#         return tempname
# </pre>

# %%
class Employee(Person):
    def __init__(self, fname, lname):
        #Person.__init__(self, fname, lname)
        super().__init__(fname, lname)
        self.office = "Seattle"
        
    def office_info(self):
        return self.fname+" "+self.lname+" of the "+self.office+" branch."
    
staffer = Employee("Anthony", "Kim")

# from the parent class: getName
staffer.getName()
# Out:
# 'Anthony Kim'

# %%
# from the child class
staffer.office_info()
# Out:
# 'Anthony Kim of the Seattle branch.'

# %% [markdown]
# <hr />
# <p><b>Note</b>: here Employee takes 3 parameters;
#     <br />The child class (Salaried) takes 4, so we can use the __init__ for the child <i>and</i> pass only the 3 <u>up</u> to the parent Employee().  The 4th parameter (<b>email</b>) is stored only in the child class (self.email = email).<br /><br />
#     Notice that all the <u>methods</u> used belong to the parent.</p>

# %%
class Employee():
    def __init__(self, id, name, address):
        self.id = id
        self.name = name
        self.address = address
 
# Class salaried inherits Employee
class Salaried(Employee):
    def __init__(self, id, name, address, email):
        super().__init__(id, name, address)
        self.email = email
 
employee_1 = Salaried(99, "Tom Daniels", "Smith St." , "tom@smithco.com")
print(f'The ID {employee_1.id}')
print(f'Info: {employee_1.name}')
print(f' at {employee_1.address}')
print(f' @ {employee_1.email}')
# Out:
# The ID 99
# Info: Tom Daniels
#  at Smith St.
#  @ tom@smithco.com

# %% [markdown]
# <hr />
# <p style="padding:10px; border-radius:5px; background-color:#3B7EA1; color:white; font-size:22px;">Examples</p>
#  <p>Notice the use of the import statements; we&rsquo;re progressing from hard-coded data towards a variety of data inputs: local, URLs, SQL, and more.</p>
# <ul>
#     <li>Import libraries</li>
#     <li>Define classes, with doc strings, accessible using __doc__</li>
#     <li>Notice the use of publicly accessible vars with dot operator and protected variables, indicated by the __, e.g., __x, which require some implementation of the get/set idea, here use we&rsquo;re using the toss() method.</li>
#     <li>Calling the action (e.g., my_coin.toss())</li>
#     <li>Use of <code>if __name__</code> as a starting point</li>
# </ul>

# %% [markdown]
# <h2 style="color:#3B7EA1;"><i>Example 1:</i></h2>

# %%
import random
import html

class Coin:
    """ 
    the __init__ method initializes the coind with Heads as attribute
    """
    def __init__(self):
        # NOTE adding the __ is a way to protect the attribute; controlling access
        self.__sideup = "Heads"  
        
        # this attribute is the coin's value - just public
        self.coinvalue = "25"
        
        # the toss method generates a random number iun range 0-1
        # if 0, then heads, if 1 then tails
        
    def toss(self):
        if random.randint(0, 1) == 0:
            self.__sideup = "Heads"
        else:
            self.__sideup = "Tails"
                
    # use the idea of get/set to GET the value referenced by the sideup attriburte
    def get_sideup(self):
        return self.__sideup

# create a STARTING POINT ("main") function - the doorway into the script.
def start_coin_game():
    my_coin = Coin()            # create an object from the Coin class
    
    # check the side that's up:
    print("We're playing with a", my_coin.coinvalue,html.unescape("&cent;"),"piece.  This side is up: ", my_coin.get_sideup())
    
    # give it a flip
    print("... tossing the coin ... ")
    my_coin.toss()
    
    print("After the flip, this side is up: ", my_coin.get_sideup())

# -----------------------------------------------------------------    
if __name__ == "__main__":
    start_coin_game()
# Out:
# We're playing with a 25 ¢ piece.  This side is up:  Heads
# ... tossing the coin ...
# After the flip, this side is up:  Tails

# %% [markdown]
# <hr />
# <h2 style="color:#3B7EA1;"><i>Example 2:</i></h2>
# <p>In the next example we integrate a number of features: constants, file reading, <code>pickle</code> for serialization of our data and more.</p>
# <p>How can you improve this code?  At the least, use a try/except block for reading/writing to the contacts.dat file.</p>

# %%
import pickle # for serialization of data we save to a file

# some global constants
LOOK_UP = 1
ADD = 2
CHANGE = 3
DELETE = 4
QUIT = 5

# constant for the filename, too
FILENAME = "contacts.dat"

# ********************************************
# define class Contact
# ********************************************

class Contact:
    """ To create a phonebook contact

    Keyword arguments:
    name -- String
    phone - phone number that should contain dashes, e.g., 555-123-3213
    email -- email string including the @ sign
    __str__ returns formatted contact info of name, phone, and email
    """
    
    def __init__(self, name, phone, email):
        self.__name = name
        self.__phone = phone
        self.__email = email
        print(email)
        
    # set_name method sets the name attribute ... and so on ...
    def set_name(self, name):
        self.__name = name
    def set_phone(self, phone):
        self.__phone
    def set_email(self, email):
        self.__email = email
        
    def get_name(self):
        return self.__name
    def get_email(self):
        return self.__email
    def get_phone(self):
        return self.__phone
    
    # __str__ method to return the object's state as a string.
    def __str__(self):
        return "\n\tName: "+self.__name + \
        "\n\tPhone: " + self.__phone + \
        "\n\tEmail: " + self.__email
    
# ********************************************
# load_contacts
# ********************************************

def load_contacts():
    try:
        input_file = open(FILENAME, 'rb')
        contact_dct = pickle.load(input_file)
        input_file.close()
    except IOError:  # can't open the file so create one.
        contact_dct = {}
    return contact_dct


# ********************************************
# get_menu_choice
# ********************************************

# control the input
def get_menu_choice():
    print("\n --- MENU ","-"*40)
    print("1 = Look up contact")
    print("2 = Add a new contact")
    print("3 = Change an existing contact")
    print("4 = Delete a contact")
    print("5 = Quit")
    
    choice = int(input("Enter your choice: "))
    # validate the choice
    while choice < LOOK_UP or choice > QUIT:
        choice = int(input("\nEnter a choice between 1 and 5"))

    return choice
    
# ********************************************
# Look up contacts
# ********************************************
def look_up(mycontacts):
    # get the name
    name = input("\nEnter a name:")
    
    print(mycontacts.get(name, "That name is not here."))
    
# ********************************************
# Add contacts
# ********************************************
def add(mycontacts):
    name = input("Name: ")
    phone = input("Phone: ")
    email = input("Email: ")
    
    # create a Contact object named entry
    entry = Contact(name, phone, email)
    
    # if the name doesn't exist in the dictionary, 
    # add it as a key with the entry object as the assoc value
    if name not in mycontacts:
        mycontacts[name] = entry
        print("\n** Entry added.  Yeah.")
    else:
        print("\n** That name is already in the list.")
        
# ********************************************
# Change an existing entry
# ********************************************
def change(mycontacts):
    name = input("\nEnter a name: ")
    
    if name in mycontacts:
        phone = input("Enter a new phone #: ")
        email = input("Input the new email address: ")
        
        entry = Contact(name, phone, email)
        
        #update the entry
        mycontacts[name] = entry
        print("Info updated.")
    else:
        print("Sorry, that name was not found.")

# ********************************************
# Delete an entry
# ********************************************
def delete(mycontacts):
    # get the name
    name = input("Enter the name: ")
    if name in mycontacts:
        del mycontacts[name]
        print("Entry deleted.")
    else:
        print("Not found.")

# ********************************************
# Save contacts
# ********************************************
def save_contacts(mycontacts):
    # open the file for writing
    output_file = open(FILENAME, "wb")
    pickle.dump(mycontacts, output_file)
    output_file.close()


# ********************************************
# Main function
# ********************************************

# main function
def phonebook():
    mycontacts = load_contacts()
    
    # init for user's choice
    choice = 0
    
    while choice != QUIT:
        choice = get_menu_choice()
        
        if choice == LOOK_UP:
            look_up(mycontacts)
        elif choice == ADD:
            add(mycontacts)
        elif choice == CHANGE:
            change(mycontacts)
        elif choice == DELETE:
            delete(mycontacts)
            
    save_contacts(mycontacts)
    
# ********************************************
# Start running the script here.
# ********************************************

if __name__ == "__main__":
    phonebook()
    #phonebook = Phonebook()
# Out:
#  --- MENU  ----------------------------------------
# 1 = Look up contact
# 2 = Add a new contact
# 3 = Change an existing contact
# 4 = Delete a contact
# 5 = Quit
# Enter your choice: 2
# Name: Toby
# Phone: 333-1234
# Email: toby@macquire.com
# toby@macquire.com
#
# ** Entry added.  Yeah.
#
#  --- MENU  ----------------------------------------
# 1 = Look up contact
# 2 = Add a new contact
# 3 = Change an existing contact
# 4 = Delete a contact
# 5 = Quit
# Enter your choice: 5

# %% [markdown]
# <div style="background-color:maroon; font-size: 18px; line-height:24px; padding: 10px; color: white;">
# Recap:
# <ul><li>Define the parent class</li>
#     <li>Define a child class <i>without</i> an __init__</li>
#     <li> ...  a child class <i>with</i> an __init__ to override the default</li>
#     <li>Adding methods only to the child</li>
#     <li>Using super()</li>
# </ul>
# </div>

# %% [markdown]
# <hr />
# <h2 style="background-color: #003262; color:white; border-radius: 4px; padding: 8px;">
# Polymorphism</h2>
# <p>Polymorphic behavior:
#     <ul>
#         <li>define a method in a superclass and then define a method with the same name in a subclass; sometimes called <i>overriding</i></li>
#         <li>ability to call the correct version of an overriden method, depending on the type of object that is used to call it.  If a subclass object is used to call an overriden method, then the subclass's version of the method will be executed.  If a superclass object isused to call an overridden method, then the superclass's version of the method is the one that&rsquo;s executed.</li>
#         <li>Recall python&rsquo;s <code>*arg</code> and <code>**kwarg</code> for passing objects of variable length as parameters</li>
#     </ul>
# </p>
# <p>Here we&rsquo;ll look at <code>__init__</code> that overrides the superclass&rsquo;s __init__ method.  When an instance of the subclass is created, it is the subclass's __init__ method that automatically gets called.</p>
# <p>The usual example is to make some pets!  Notice each class has the same method name - <code>show_mammal_info()</code>.</p>
# <blockquote>Note that we&rsquo;re introducing more and more modules and to encode data in different ways.  Notice the <code>unicode</code> module, the use of <code>\N{<i>x</i>}</code>, and protected variables with the dunder.  <br />Unicode is the <i>standard</i> that defines each code point; that python can express in binary, octal, decimal, hexadecimal, <a href="https://unicode.org" target="new">unicode</a> glyph name, code point. </blockquote>

# %% [markdown]
# <hr />
# <h2 style="color:#3B7EA1;"><i>Example 3:</i></h2>
# <p>Here we want to emphasize the internationalization of communicating with the end-user and the increasing use of Unicode and icons.  Please note the many ways we&rsquo;re using the parent and child classes.  There&rsquo;s no right/wrong technique - only what you can code, maintain, scale and document.</p>

# %%
import unicodedata

class Mammal:
    # the __init__ accepts an argument for the species
    def __init__(self, species):
        self.__species = species
        
    # the show_speciees method displays a message about the mammal's species
    def show_species(self):
        print("I'm a ", self.__species)
        
    # make some generic sound ...
    def make_sound(self):
        print("\t\t \N{DOLPHIN} Roar of the Dolphin!")
        
class Dog(Mammal):
    
    # the __init__here calls the superclass's __init__ passing "Dog" as species
    def __init__(self):
        Mammal.__init__(self, "Dog")
        
    # here we'll override the superclass's make_sound() method.
    def make_sound(self):
        print("\t\t \N{DOG} Woof!")
        
class Cat(Mammal):
    
    # the __init__here calls the superclass's __init__ passing "Cat" as species
    def __init__(self):
        Mammal.__init__(self, "Cat")
        
    # here we'll override the superclass's make_sound() method.
    def make_sound(self):
        print("M e o o w ! \N{CAT}")
        
def animal_show():
    # create a Mammal, Dog, and Cat objects
    mammal = Mammal('Regular Mammal ')
    dog = Dog()
    cat = Cat()
    
    print("What do they say?")
    show_mammal_info(mammal)
    show_mammal_info(dog)
    show_mammal_info(cat)
    
# a way of getting info showing polymorphism.
def show_mammal_info(creature):
    creature.show_species()
    creature.make_sound()

    
if __name__ == "__main__":
    animal_show()
# Out:
# What do they say?
# I'm a  Regular Mammal
# 		 🐬 Roar of the Dolphin!
# I'm a  Dog
# 		 🐕 Woof!
# I'm a  Cat
# M e o o w ! 🐈

# %% [markdown]
# <hr />
# <h2 style="background-color: #003262; color:white; border-radius: 4px; padding: 8px;">
#     Part 2: Magic Methods
# </h2>
#     <p>As we know our scripts inherit from Python a great number of __dunder__ variables and methods.  Python allows us access to those vars/methods and our own.  We can leverage this idea to compare <i>objects</i>.
#     </p>
#     <p>Why?  To compare variables, such as x = 5 to y = 20, is easy enough; but how to compare our own objects?  We have to select some criterion or set of criteria that are comparable.  Then we must <u>override</u> Python&rsquo;s built-in __ such as __eq__ equals, __lt__, __gt__, and so on.  Imagine if discussing financial institutions, we might wonder Bank is &ldquo;bigger&rdquo;?  Bigger must be defined by some attribute of the object we can compare.</p>
# <p>We can override how python does comparisons - by overriding the <b>magic methods</b>.</p>

# %% [markdown]
# <h2> &#127752; Magic Methods</h2>
# <table align="left" width="100%">
#     <tr>
#         <td style="text-align: left;">__eq__(self, other)</td>
#         <td  style="text-align: left;">__ne__(self, other)</td>
#         <td  style="text-align: left;">__lt__(self, other)</td>
#     </tr>
#     <tr>
#         <td style="text-align: left;">__gt__(self, other)</td>
#         <td style="text-align: left;">__le__(self, other)</td>
#         <td style="text-align: left;">__ge__(self, other)</td>
#     </tr>
#     <tr>
#         <td style="text-align: left;">__add__(self, other)</td>
#         <td style="text-align: left;">__sub__(self, other)</td>
#         <td style="text-align: left;">__mul__(self, other)</td>
#     </tr>
#     <tr>
#         <td style="text-align: left;">__floordiv__(self, other)</td>
#         <td style="text-align: left;">__truediv__(self, other)</td>
#         <td style="text-align: left;">__mod__(self, other)</td>
#     </tr>
#     <tr>
#         <td style="text-align: left;">__pow__(self, other)</td>
#         <td style="text-align: left;">__str__(self)</td>
#         <td style="text-align: left;">__repr__(self)</td>
#     </tr>
#     <tr>
#         <td style="text-align: left;">__len__(self)</td>
#         <td style="text-align: left;">__name__(self)</td>
#         <td style="text-align: left;">__main__</td>
#     </tr>
#     </table>

# %% [markdown]
# <hr />
# <p>Take a careful look at each of the lines below: notice we are overwriting the default behavior of python's __ variables.  We can compare objects <i>only</i> when we decide what aspects are to be compared.  That depends on our situational context.</p>

# %%
class Comparison:
    def __init__(self, a):
        self.a = a
    def __lt__(self, object2):
        return self.a < object2.a
    def __gt__(self, object2):
        return self.a > object2.a
    def __le__(self, object2):
        return self.a <= object2.a
    def __ge__(self, object2):
        return self.a >= object2.a
    def __eq__(self, object2):
        return self.a == object2.a
    def __ne__(self, object2):
        return self.a != object2.a
    
a = Comparison(1)
b = Comparison(2)

print(
    a < b,
    a > b,
    a <= b,
    a >= b,
    a == b,
    a != b
)
# Out:
# True False True False False True

# %%
class Card:
    
    def __init__(self, value, suit): # invoked automaically when object is created
        self.value = value
        self.suit = suit
    

a = Card(3, "heart")
b = Card(5, "spade")

# is a equivalent to a
a == a

# c is copied from a: is c equivalent to a
c = a
a == c

a == b
a < b

a > b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 19
#      16 a == c
#      18 a == b
# ---> 19 a < b
#      21 a > b
#
# TypeError: '<' not supported between instances of 'Card' and 'Card'

# %%
class Card:
    
    def __init__(self, value, suit): # invoked automaically when object is created
        self.value = value
        self.suit = suit
        
    def __eq__(self, other): # invoked automatically when == is used with two Card objects
        return self.value == other.value # will return True or False

    def __lt__(self, other): # invoked automatically when < is used with two Card objects
        return self.value < other.value # will return True or False
    
    def __gt__(self, other): # invoked automatically when > is used with two Card objects
        return self.value > other.value # will return True or False
    

a = Card(3, "heart")
b = Card(5, "spade")

a == a

c = a
a == c

a == b
a < b
a > b
# Out:
# False

# %% [markdown]
# <hr />
# <h2 style="background-color: #003262; color:white; border-radius: 4px; padding: 8px;">
# Part 3: Static and Protected
# </h2>
# <p>Finally, there are options to control how we use/store variables - a static variable is stored in one part of RAM and not allowed to change for efficiencies&rsquo; sake; class methods affect entire classes.  In short, while Python allows us the traditional object-hierarchy, it allows also considerable mastery over the software and hardware contributions to our code&rsquo;s efficiency and effectiveness.</p>
# <p>The below ProtectedBank

# %%
""" ___________________________________
Example using CLASSMETHOD and STATIC
"""

class ProtectedBanks:
    """ Base class for all ProtectedBanks """
    __total_branches = 0

    def __init__(self, name, city, money_on_hand = 10000):
        self.name = name
        self.city = city
        self.no_of_transactions = 0
        self.__money_on_hand = money_on_hand
        ProtectedBanks.__total_branches += 1
        ProtectedBanks.preferred_currency = "USD"

    def how_much_in_vault(self):
        # print("$ in vault: ", moneyOnHand) - throws error now
        return self.__money_on_hand

    @classmethod
    def get_total_branches(cls):
        return cls.__total_branches
    
    @staticmethod
    def convert_from_USD_to_Yuan(amount):
        return amount * 0.16

# %% [markdown]
# <hr /><p>A final bit of fun.  Not all objects have to look like humans or dogs.  What about coding activities?  Here&rsquo;s an example of renaming files from an OOP p.o.v.</p>
# <p>In this example notice the -en, -zh, examples of <a href="https://www.iso.org/iso-639-language-codes.html" target="new">ISO 639-2</a>.  Try to use industrial standards whenever possible.</p>

# %%
import os

class RenameFileCommand(object):
    def __init__(self, from_name, to_name):
        self._from = from_name
        self._to = to_name

    def execute(self):
        os.rename(self._from, self._to)

    def undo(self):
        os.rename(self._to, self._from)

class History(object):
    def __init__(self):
        self._commands = list()

    def execute(self, command):
        self._commands.append(command)
        command.execute()

    def undo(self):
        self._commands.pop().undo()

history = History()
history.execute(RenameFileCommand('docs/cv.txt', 'docs/cv-en.txt'))
history.execute(RenameFileCommand('docs/cv1.txt', 'docs/cv-zh.txt'))

history.undo()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [1], in <cell line: 26>()
#      23         self._commands.pop().undo()
#      25 history = History()
# ---> 26 history.execute(RenameFileCommand('docs/cv.txt', 'docs/cv-en.txt'))
#      27 history.execute(RenameFileCommand('docs/cv1.txt', 'docs/cv-zh.txt'))
#      29 history.undo()
#
# Input In [1], in History.execute(self, command)
#      18 def execute(self, command):
#      19     self._commands.append(command)
# ---> 20     command.execute()
#
# Input In [1], in RenameFileCommand.execute(self)
#       8 def execute(self):
# ----> 9     os.rename(self._from, self._to)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'docs/cv.txt' -> 'docs/cv-en.txt'

# %% [markdown]
# <hr />
# <h2 style="background-color: #003262; color:white; border-radius: 4px; padding: 8px;">
# Part 4: Demo application</h2>
# <p>In this example, I&rsquo;ve integrated a variety of techniques used in practice.  The code can certainly be improved!</p>

# %%
from datetime import datetime

SAVEDEBUGINFO = False

class Menu:
    def __init__(self):
        self.__lang_choice = input("Enter a 2-letter ISO lang code option [en, zh, hi]:")

    def get_lang_choice(self):
        return self.__lang_choice  

class Msg_board:
    def __init__(self, stringToShow):
        self.stringToShow = stringToShow
        
    def setMessage(self, newString):
        self.stringToShow = newString
        
    def showMessage(self):
        print(f"User message:  {self.stringToShow}.")
        
class File_Reader:
    def __init__(self, lang_code, msg_board):
        self.lang_code = lang_code
        self.file_name = "docs/cv-"+lang_code+".txt"
        
        try:
            f = open(self.file_name, 'r')
            print(f.read())
            f.close()
        except IOError:
            print(f"Sorry, the file {self.file_name} isn't available.")
            
            if SAVEDEBUGINFO:
                try:
                    with open("error.log", "a") as outfile:
                        outfile.write(debuginfo)
                except IOError:
                    print("\n\nCannot access error.log.\n\n")
                
        else:
            msg_board.setMessage("File found.  One moment ... ")
            msg_board.showMessage()
        finally:
            msg_board.setMessage("\n---Done---")
            msg_board.showMessage()
   
    def __str__(self):
        return f'Language chosen is {self.lang_code}'
    
    def __repr__(self):
        now = datetime.now()
        dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
        
        debuginfo = "File access at "+dt_string+"\n"
        debuginfo += str(File_Reader.__dict__)
        
        return debuginfo        

class Start:
    options = Menu()
    msg_board = Msg_board(options.get_lang_choice())
    msg_board.showMessage()
    fr = File_Reader(options.get_lang_choice(), msg_board)
    
    print(fr.__str__)
  

if __name__ == "__main__":
    Start()
    #s = Start()

# %% [markdown]
# <hr />
# <h2>Activity: <a href='activity/week_08_activity.ipynb' target='new'>Activity</a> and
#     <a href="activity/week_08_activity (solution).ipynb" target="new">Solution</a></h2>
#     <hr />
# <h1>Part 5: Optional: Review of Get-Set and Property Decorators</h1>
# <blockquote>Building Up and Integrating get/set and property decorators.</h1>
# <p><a href="Fa23/w8/wk8_get_set.ipynb" target="new">Optional Sequential review of get/set</a>
#     </p>

# %% [markdown]
# <hr />
# <p style="font-size:24px; color:red; padding:10px;">End of Week 08</p>
